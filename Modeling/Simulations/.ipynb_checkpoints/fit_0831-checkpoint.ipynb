# %%
# test the fitting:
# Chi2 on lag-hr, hard bound = False

# %%
import pickle
import glob
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from optimization_utils import param_vec_to_dict, make_boundary
import scipy.optimize as opt
import scipy.stats as st

# %%
folder = "0831_ML_50_100/"

# %%
file_list = glob.glob(folder + "outfiles/*data*.pkl")
file_list = [i.replace(folder + "outfiles/","") for i in file_list]
file_list = [i.replace(".pkl","") for i in file_list]
file_list = [tuple(map(int,i.split("data"))) for i in file_list]
file_list.sort()
# file_list

# %%
pso_df = pd.DataFrame(columns = ['iter','particle','err'])
_, _, what_to_fit = make_boundary()

for iter, p in file_list:
    path = folder + "outfiles/" + str(iter) + "data" + str(p) + ".pkl" 
    with open(path, 'rb') as inp:
        data = pickle.load(inp)
    if len(data) != 0:
        err = data['err']
        params = data['params']
        row_dict = {"iter":iter,"particle":p,"err":err}
        row_dict.update({what_to_fit[i]:params[i] for i in range(len(params))})
        pso_df = pso_df.append(row_dict,ignore_index=True)
    
pso_df
# Out:
#       iter  particle            err  beta_enc  beta_rec_post  c_thresh  \
# 0      1.0       0.0 -260857.418723  0.768369       0.260722  0.328510
# 1      1.0       1.0 -327045.952753  0.715856       0.315853  0.579622
# 2      1.0       2.0 -232618.164973  0.215181       0.099252  0.022628
# 3      1.0       3.0 -258653.877283  0.134403       0.288182  0.520273
# 4      1.0       4.0 -280235.550996  0.464602       0.253742  0.155762
# ...    ...       ...            ...       ...            ...       ...
# 4995  50.0      95.0   13162.444464  0.425623       0.848502  0.670167
# 4996  50.0      96.0 -459255.051315  0.805374       0.876441  0.891523
# 4997  50.0      97.0    6989.081622  0.559510       0.888312  0.818316
# 4998  50.0      98.0 -438709.532006  0.555025       0.802282  0.687946
# 4999  50.0      99.0  278589.073231  0.463304       0.990000  0.765277
#
#       gamma_fc      s_fc
# 0     0.826631  0.195994
# 1     0.727791  0.337664
# 2     0.160975  0.705290
# 3     0.969839  0.917381
# 4     0.124727  0.366538
# ...        ...       ...
# 4995  0.990000  1.000000
# 4996  0.983315  0.727937
# 4997  0.990000  0.911748
# 4998  0.986344  0.983993
# 4999  0.953398  0.805734
#
# [5000 rows x 8 columns]

# %%
pso_df.loc[pso_df.iter == 50]
# Out:
#       iter  particle            err  beta_enc  beta_rec_post  c_thresh  \
# 4900  50.0       0.0  -33575.232814  0.795154       0.945500  0.619013
# 4901  50.0       1.0  280714.051483  0.100000       0.932945  0.000000
# 4902  50.0       2.0 -207416.432849  0.580046       0.982137  0.865685
# 4903  50.0       3.0 -471274.413465  0.600922       0.859255  0.617934
# 4904  50.0       4.0  282331.876540  0.210543       0.984943  0.625358
# ...    ...       ...            ...       ...            ...       ...
# 4995  50.0      95.0   13162.444464  0.425623       0.848502  0.670167
# 4996  50.0      96.0 -459255.051315  0.805374       0.876441  0.891523
# 4997  50.0      97.0    6989.081622  0.559510       0.888312  0.818316
# 4998  50.0      98.0 -438709.532006  0.555025       0.802282  0.687946
# 4999  50.0      99.0  278589.073231  0.463304       0.990000  0.765277
#
#       gamma_fc      s_fc
# 4900  0.859650  0.920628
# 4901  0.990000  1.000000
# 4902  0.989013  0.679367
# 4903  0.990000  0.931352
# 4904  0.987720  0.847779
# ...        ...       ...
# 4995  0.990000  1.000000
# 4996  0.983315  0.727937
# 4997  0.990000  0.911748
# 4998  0.986344  0.983993
# 4999  0.953398  0.805734
#
# [100 rows x 8 columns]

# %%
sns.scatterplot(data=pso_df, x="iter", y="err", hue="particle")
plt.show()

# %%
sns.scatterplot(data=pso_df, x="iter", y="err")
plt.show()

# %%
sns.scatterplot(data=pso_df, x="iter", y="gamma_fc")
plt.show()

# %%
param_vec = np.loadtxt('/home1/beigejin/MyCMR2/Modeling/CMR2/fitting/' + folder + 'outfiles/xoptb.txt')
prams = param_vec_to_dict(param_vec)
prams
# Out:
# {'beta_enc': 0.635041,
#  'beta_rec': 0.5,
#  'beta_rec_post': 0.888809,
#  'beta_distract': None,
#  'phi_s': 2,
#  'phi_d': 0.5,
#  's_cf': 0,
#  's_fc': 0.827982,
#  'kappa': 0.5,
#  'eta': 0.5,
#  'omega': 8,
#  'alpha': 4,
#  'c_thresh': 0.814633,
#  'lamb': 0.5,
#  'rec_time_limit': 60000.0,
#  'dt': 10,
#  'nitems_in_accumulator': 50,
#  'max_recalls': 50,
#  'learn_while_retrieving': False,
#  'gamma_fc': 0.971833,
#  'gamma_cf': 0.5}

# %% [markdown]
# ### Run CMR2 on the Best Params

# %%
import CMR2_jbg as cmr
pd.set_option('display.max_columns', None)
np.set_printoptions(edgeitems=20, linewidth=200,precision=4)

# %%
rng = np.random.default_rng(seed=42)

# %%
# import recognition dataframe
with open("/home1/beigejin/Recog_David/data_als/data_df_clean.pkl", 'rb') as inp:
    df = pickle.load(inp)
df
# Out:
#               rt  subject_ID       item  lag                 category  \
# 57307   1514.875           0    CHICKEN    0            Uncategorized
# 57766    853.505           0  BLUEBERRY    0            Uncategorized
# 58224    731.040           0        BUS    0            Uncategorized
# 58695    848.955           0      LEMON    0            Uncategorized
# 59159    643.880           0     OYSTER    0            Uncategorized
# ...          ...         ...        ...  ...                      ...
# 337333  1911.000         656       COLA   37                Beverages
# 337508  2358.000         656   BASEBALL  115                     Toys
# 337682  1239.000         656        TEA   24                Beverages
# 337870  1567.000         656      RADIO   41  Uncategorized-Singleton
# 338047  1355.000         656      FINCH   81                    Birds
#
#         confidence category_label  position    old  yes  curr_cat_length  \
# 57307          1.0    FarmAnimals         0  False    0              NaN
# 57766          1.0          Fruit         1  False    0              NaN
# 58224          1.0       Vehicles         2  False    0              NaN
# 58695          1.0          Fruit         3  False    0              NaN
# 59159          1.0   OceanAnimals         4  False    0              NaN
# ...            ...            ...       ...    ...  ...              ...
# 337333         2.0      Beverages       575   True    0             18.0
# 337508         8.0           Toys       576   True    1             23.0
# 337682         8.0      Beverages       577   True    1             19.0
# 337870         2.0    Electronics       578   True    0              NaN
# 338047         8.0          Birds       579   True    1             22.0
#
#         curr_cat_label_length  itemno  session
# 57307                       0      53        0
# 57766                       0      26        0
# 58224                       0      33        0
# 58695                       1     151        0
# 59159                       0     187        0
# ...                       ...     ...      ...
# 337333                     18      60      350
# 337508                     23      10      350
# 337682                     19     265      350
# 337870                     23     213      350
# 338047                     22      99      350
#
# [203580 rows x 14 columns]

# %%
s_mat = np.load('/home1/beigejin/Recog_David/data_als/semantic_mat_fasttext.npy')

# %%
df_simu = cmr.run_continuous_recog_multi_sess(prams,df,s_mat)
df_simu
# Out:
# CMR Time: 144.32454800605774
#         session  position  itemno  s_resp  s_rt      csim
# 57307         0         0      53     0.0   0.0  0.000000
# 57766         0         1      26     0.0   0.0  0.276770
# 58224         0         2      33     0.0   0.0  0.338629
# 58695         0         3     151     0.0   0.0  0.362394
# 59159         0         4     187     0.0   0.0  0.374427
# ...         ...       ...     ...     ...   ...       ...
# 337333      350       575      60     0.0   0.0  0.383132
# 337508      350       576      10     0.0   0.0  0.384021
# 337682      350       577     265     0.0   0.0  0.383658
# 337870      350       578     213     0.0   0.0  0.387573
# 338047      350       579      99     0.0   0.0  0.380820
#
# [203580 rows x 6 columns]

# %%
df_new = df_simu.merge(df,on=['session','position','itemno'])
df_new
# Out:
#         session  position  itemno  s_resp  s_rt      csim        rt  \
# 0             0         0      53     0.0   0.0  0.000000  1514.875
# 1             0         1      26     0.0   0.0  0.276770   853.505
# 2             0         2      33     0.0   0.0  0.338629   731.040
# 3             0         3     151     0.0   0.0  0.362394   848.955
# 4             0         4     187     0.0   0.0  0.374427   643.880
# ...         ...       ...     ...     ...   ...       ...       ...
# 203575      350       575      60     0.0   0.0  0.383132  1911.000
# 203576      350       576      10     0.0   0.0  0.384021  2358.000
# 203577      350       577     265     0.0   0.0  0.383658  1239.000
# 203578      350       578     213     0.0   0.0  0.387573  1567.000
# 203579      350       579      99     0.0   0.0  0.380820  1355.000
#
#         subject_ID       item  lag                 category  confidence  \
# 0                0    CHICKEN    0            Uncategorized         1.0
# 1                0  BLUEBERRY    0            Uncategorized         1.0
# 2                0        BUS    0            Uncategorized         1.0
# 3                0      LEMON    0            Uncategorized         1.0
# 4                0     OYSTER    0            Uncategorized         1.0
# ...            ...        ...  ...                      ...         ...
# 203575         656       COLA   37                Beverages         2.0
# 203576         656   BASEBALL  115                     Toys         8.0
# 203577         656        TEA   24                Beverages         8.0
# 203578         656      RADIO   41  Uncategorized-Singleton         2.0
# 203579         656      FINCH   81                    Birds         8.0
#
#        category_label    old  yes  curr_cat_length  curr_cat_label_length
# 0         FarmAnimals  False    0              NaN                      0
# 1               Fruit  False    0              NaN                      0
# 2            Vehicles  False    0              NaN                      0
# 3               Fruit  False    0              NaN                      1
# 4        OceanAnimals  False    0              NaN                      0
# ...               ...    ...  ...              ...                    ...
# 203575      Beverages   True    0             18.0                     18
# 203576           Toys   True    1             23.0                     23
# 203577      Beverages   True    1             19.0                     19
# 203578    Electronics   True    0              NaN                     23
# 203579          Birds   True    1             22.0                     22
#
# [203580 rows x 17 columns]

# %%
def mse(c, df):
    
    df_new = df.loc[df.old == False]
    tar_far = df_new.yes.mean()
    
    csim_new = df_new.csim.to_numpy()
    far = np.sum(csim_new > c) / len(csim_new)
    
    df_old = df.loc[df.old == True]
    tar_hr = df_old.yes.mean()
    
    csim_old = df_old.csim.to_numpy()
    hr = np.sum(csim_old > c) / len(csim_old)
    
    mse = (far - tar_far)**2 + (hr - tar_hr)**2
    
    return mse

# %%
def mle(df):
    
    res = opt.minimize(
        fun=lambda c, df: mse(c, df),
        x0=0.37, args=(df,), method='Nelder-Mead')
    
    c = res.x.item()
    
    return c, res

# %%
c, res = mle(df_new)
c
# Out:
# 0.3772265625

# %%
res

# %%
import math
math.sqrt(res.fun)
# Out:
# 0.15517183402931903

# %%
df_new['s_resp'] = df_new['csim'] > c
df_new = df_new.astype({'s_resp': 'int32'})
df_new
# Out:
#         session  position  itemno  s_resp  s_rt      csim        rt  \
# 0             0         0      53       0   0.0  0.000000  1514.875
# 1             0         1      26       0   0.0  0.276770   853.505
# 2             0         2      33       0   0.0  0.338629   731.040
# 3             0         3     151       0   0.0  0.362394   848.955
# 4             0         4     187       0   0.0  0.374427   643.880
# ...         ...       ...     ...     ...   ...       ...       ...
# 203575      350       575      60       1   0.0  0.383132  1911.000
# 203576      350       576      10       1   0.0  0.384021  2358.000
# 203577      350       577     265       1   0.0  0.383658  1239.000
# 203578      350       578     213       1   0.0  0.387573  1567.000
# 203579      350       579      99       1   0.0  0.380820  1355.000
#
#         subject_ID       item  lag                 category  confidence  \
# 0                0    CHICKEN    0            Uncategorized         1.0
# 1                0  BLUEBERRY    0            Uncategorized         1.0
# 2                0        BUS    0            Uncategorized         1.0
# 3                0      LEMON    0            Uncategorized         1.0
# 4                0     OYSTER    0            Uncategorized         1.0
# ...            ...        ...  ...                      ...         ...
# 203575         656       COLA   37                Beverages         2.0
# 203576         656   BASEBALL  115                     Toys         8.0
# 203577         656        TEA   24                Beverages         8.0
# 203578         656      RADIO   41  Uncategorized-Singleton         2.0
# 203579         656      FINCH   81                    Birds         8.0
#
#        category_label    old  yes  curr_cat_length  curr_cat_label_length
# 0         FarmAnimals  False    0              NaN                      0
# 1               Fruit  False    0              NaN                      0
# 2            Vehicles  False    0              NaN                      0
# 3               Fruit  False    0              NaN                      1
# 4        OceanAnimals  False    0              NaN                      0
# ...               ...    ...  ...              ...                    ...
# 203575      Beverages   True    0             18.0                     18
# 203576           Toys   True    1             23.0                     23
# 203577      Beverages   True    1             19.0                     19
# 203578    Electronics   True    0              NaN                     23
# 203579          Birds   True    1             22.0                     22
#
# [203580 rows x 17 columns]

# %%
f = folder.rstrip("/")

# %%
with open('/home1/beigejin/Recog_David/data_als/data_df_simu_' + f + '.pkl', 'wb') as outp:
    pickle.dump(df_new, outp, pickle.HIGHEST_PROTOCOL)

# %%
# import dataframe with both real data and simulation data
f = "0831_ML_50_100"

with open("/home1/beigejin/Recog_David/data_als/data_df_simu_" + f + ".pkl", 'rb') as inp:
    df_new = pickle.load(inp)
df_new
# Out:
#         session  position  itemno  s_resp  s_rt      csim        rt  \
# 0             0         0      53       0   0.0  0.000000  1514.875
# 1             0         1      26       0   0.0  0.276770   853.505
# 2             0         2      33       0   0.0  0.338629   731.040
# 3             0         3     151       0   0.0  0.362394   848.955
# 4             0         4     187       0   0.0  0.374427   643.880
# ...         ...       ...     ...     ...   ...       ...       ...
# 203575      350       575      60       1   0.0  0.383132  1911.000
# 203576      350       576      10       1   0.0  0.384021  2358.000
# 203577      350       577     265       1   0.0  0.383658  1239.000
# 203578      350       578     213       1   0.0  0.387573  1567.000
# 203579      350       579      99       1   0.0  0.380820  1355.000
#
#         subject_ID       item  lag                 category  confidence  \
# 0                0    CHICKEN    0            Uncategorized         1.0
# 1                0  BLUEBERRY    0            Uncategorized         1.0
# 2                0        BUS    0            Uncategorized         1.0
# 3                0      LEMON    0            Uncategorized         1.0
# 4                0     OYSTER    0            Uncategorized         1.0
# ...            ...        ...  ...                      ...         ...
# 203575         656       COLA   37                Beverages         2.0
# 203576         656   BASEBALL  115                     Toys         8.0
# 203577         656        TEA   24                Beverages         8.0
# 203578         656      RADIO   41  Uncategorized-Singleton         2.0
# 203579         656      FINCH   81                    Birds         8.0
#
#        category_label    old  yes  curr_cat_length  curr_cat_label_length
# 0         FarmAnimals  False    0              NaN                      0
# 1               Fruit  False    0              NaN                      0
# 2            Vehicles  False    0              NaN                      0
# 3               Fruit  False    0              NaN                      1
# 4        OceanAnimals  False    0              NaN                      0
# ...               ...    ...  ...              ...                    ...
# 203575      Beverages   True    0             18.0                     18
# 203576           Toys   True    1             23.0                     23
# 203577      Beverages   True    1             19.0                     19
# 203578    Electronics   True    0              NaN                     23
# 203579          Birds   True    1             22.0                     22
#
# [203580 rows x 17 columns]

# %%
bin_arr = np.arange(0,1,0.005)
df_tar = df_new.loc[df_new.old == True]
df_lure = df_new.loc[df_new.old == False]

fig, ax = plt.subplots()
df_tar.hist(column = 'csim', bins=bin_arr, ax = ax, density = True,alpha=0.5)
df_lure.hist(column = 'csim', bins=bin_arr, ax = ax, density = True, alpha=0.5)
plt.axvline(prams["c_thresh"], color = 'k')
plt.show()

# %%
bin_arr = np.arange(0.2,0.4,0.001)
df_tar = df_new.loc[df_new.old == True]
df_lure = df_new.loc[df_new.old == False]

fig, ax = plt.subplots()
df_tar.hist(column = 'csim', bins=bin_arr, ax = ax, density = False,alpha=0.5)
df_lure.hist(column = 'csim', bins=bin_arr, ax = ax, density = False, alpha=0.5)
plt.axvline(c, color = 'k')
plt.show()

# %%
def loftus_masson(df, sub_cols, cond_col, value_col, within_cols=[]):
    
    if not isinstance(sub_cols, list):
        sub_cols = [sub_cols]
    if not isinstance(within_cols, list):
        within_cols = [within_cols]
    df = df.copy()
    if len(within_cols) > 0:
        df['M'] = df.groupby(within_cols)[value_col].transform('mean')
    else:
        df['M'] = df[value_col].mean()
    df['M_S'] = df.groupby(sub_cols + within_cols)[value_col].transform('mean')
    df['adj_' + value_col] = (df[value_col] + df['M'] - df['M_S'])
    
    return df

# %%
df_new = df_new.loc[(df_new.rt < 3000) & (df_new.rt > 400)&(df_new.position > 10)&(df_new.old == df_new.yes)]
df_new = loftus_masson(df_new, 'subject_ID', [], 'rt')
df_new
# Out:
#         session  position  itemno  s_resp  s_rt      csim        rt  \
# 11            0        11     246       1   0.0  0.383805   582.095
# 12            0        12      41       0   0.0  0.372918   680.490
# 13            0        13      89       0   0.0  0.368285   892.380
# 14            0        14      62       0   0.0  0.374008   912.085
# 15            0        15     274       0   0.0  0.376581  1030.440
# ...         ...       ...     ...     ...   ...       ...       ...
# 203572      350       572     291       1   0.0  0.387050  1522.000
# 203573      350       573      84       1   0.0  0.384026  1545.000
# 203576      350       576      10       1   0.0  0.384021  2358.000
# 203577      350       577     265       1   0.0  0.383658  1239.000
# 203579      350       579      99       1   0.0  0.380820  1355.000
#
#         subject_ID      item  lag                 category  confidence  \
# 11               0   SPARROW    0                    Birds         1.0
# 12               0  CARDINAL    0                    Birds         1.0
# 13               0      DRUM    0            Uncategorized         1.0
# 14               0  COMPUTER    0            Uncategorized         1.0
# 15               0     TRAIN    0  Uncategorized-Singleton         1.0
# ...            ...       ...  ...                      ...         ...
# 203572         656     WATER   29                Beverages         8.0
# 203573         656      DOVE   84                    Birds         8.0
# 203576         656  BASEBALL  115                     Toys         8.0
# 203577         656       TEA   24                Beverages         8.0
# 203579         656     FINCH   81                    Birds         8.0
#
#        category_label    old  yes  curr_cat_length  curr_cat_label_length  \
# 11              Birds  False    0              5.0                      5
# 12              Birds  False    0              6.0                      6
# 13        Instruments  False    0              NaN                      0
# 14        Electronics  False    0              NaN                      0
# 15           Vehicles  False    0              NaN                      1
# ...               ...    ...  ...              ...                    ...
# 203572      Beverages   True    1             17.0                     17
# 203573          Birds   True    1             21.0                     21
# 203576           Toys   True    1             23.0                     23
# 203577      Beverages   True    1             19.0                     19
# 203579          Birds   True    1             22.0                     22
#
#                  M          M_S       adj_rt
# 11      1275.22641  1394.877643   462.443767
# 12      1275.22641  1394.877643   560.838767
# 13      1275.22641  1394.877643   772.728767
# 14      1275.22641  1394.877643   792.433767
# 15      1275.22641  1394.877643   910.788767
# ...            ...          ...          ...
# 203572  1275.22641  1407.889849  1389.336562
# 203573  1275.22641  1407.889849  1412.336562
# 203576  1275.22641  1407.889849  2225.336562
# 203577  1275.22641  1407.889849  1106.336561
# 203579  1275.22641  1407.889849  1222.336562
#
# [155057 rows x 20 columns]

# %%
a = 2800
c = 0.3772

# %%
df_new['temp'] = a * np.exp(-1 * np.abs(df_new.csim - c))
b = np.log(df_new.rt.mean()/a) / np.log(df_new.temp.mean()/a)
b
# Out:
# 127.45489507675632

# %%
b = 170
df_new['s_rt'] = a * np.exp(-1 * b * np.abs(df_new.csim - c))

# %%
df_new.rt.mean()
# Out:
# 1275.2264104816295

# %%
df_new.s_rt.mean()
# Out:
# 1272.1018707047074

# %%
df_old = df_new.loc[df_new.lag > 0]
df_old
# Out:
#         session  position  itemno  s_resp         s_rt      csim        rt  \
# 23            0        23      71       0  1467.847736  0.373401  1116.505
# 25            0        25      38       1  2660.875722  0.377500   827.260
# 26            0        26      33       1  1828.283030  0.379707  1204.710
# 34            0        34     115       0  1501.286481  0.373534  1290.270
# 35            0        35     187       1   687.436039  0.385461   806.505
# ...         ...       ...     ...     ...          ...       ...       ...
# 203572      350       572     291       1   524.759510  0.387050  1522.000
# 203573      350       573      84       1   877.331841  0.384026  1545.000
# 203576      350       576      10       1   878.158984  0.384021  2358.000
# 203577      350       577     265       1   934.112740  0.383658  1239.000
# 203579      350       579      99       1  1513.225865  0.380820  1355.000
#
#         subject_ID        item  lag  ... confidence  category_label   old  \
# 23               0        CROW   15  ...        8.0           Birds  True
# 25               0  CALCULATOR    1  ...        8.0     Electronics  True
# 26               0         BUS   24  ...        8.0        Vehicles  True
# 34               0     GIRAFFE   29  ...        8.0             Zoo  True
# 35               0      OYSTER   31  ...        8.0    OceanAnimals  True
# ...            ...         ...  ...  ...        ...             ...   ...
# 203572         656       WATER   29  ...        8.0       Beverages  True
# 203573         656        DOVE   84  ...        8.0           Birds  True
# 203576         656    BASEBALL  115  ...        8.0            Toys  True
# 203577         656         TEA   24  ...        8.0       Beverages  True
# 203579         656       FINCH   81  ...        8.0           Birds  True
#
#         yes  curr_cat_length  curr_cat_label_length           M          M_S  \
# 23        1              7.0                      7  1275.22641  1394.877643
# 25        1              NaN                      2  1275.22641  1394.877643
# 26        1              NaN                      2  1275.22641  1394.877643
# 34        1              NaN                      2  1275.22641  1394.877643
# 35        1              NaN                      2  1275.22641  1394.877643
# ...     ...              ...                    ...         ...          ...
# 203572    1             17.0                     17  1275.22641  1407.889849
# 203573    1             21.0                     21  1275.22641  1407.889849
# 203576    1             23.0                     23  1275.22641  1407.889849
# 203577    1             19.0                     19  1275.22641  1407.889849
# 203579    1             22.0                     22  1275.22641  1407.889849
#
#              adj_rt         temp
# 23       996.853767  2789.383108
# 25       707.608767  2799.160717
# 26      1085.058767  2792.988335
# 34      1170.618767  2789.752728
# 35       686.853767  2776.963893
# ...             ...          ...
# 203572  1389.336562  2772.556453
# 203573  1412.336562  2780.951149
# 203576  2225.336562  2780.966564
# 203577  1106.336561  2781.977212
# 203579  1222.336562  2789.882723
#
# [75240 rows x 21 columns]

# %%
df_laggp = df_old.groupby('lag').s_rt.mean().to_frame(name='rt_mean').reset_index()
df_laggp.lag = df_laggp.lag.astype('int')
df_laggp = df_laggp.loc[df_laggp.lag <= 40]
# df_laggp = df_laggp.loc[df_laggp.lag.isin([1,2,4,8,16,32,40])]
sns.scatterplot(data=df_laggp, y='rt_mean', x='lag')
plt.xlabel('lag')
plt.ylabel('s_rt')
plt.show()

# %%
df_laggp = df_old.groupby('lag').csim.mean().to_frame(name='rt_mean').reset_index()
df_laggp.lag = df_laggp.lag.astype('int')
df_laggp = df_laggp.loc[df_laggp.lag <= 40]
# df_laggp = df_laggp.loc[df_laggp.lag.isin([1,2,4,8,16,32,40])]
sns.scatterplot(data=df_laggp, y='rt_mean', x='lag')
plt.xlabel('lag')
plt.ylabel('csim')
plt.show()

# %%
df_new.hist(column = 's_rt', bins=np.arange(400,3000), cumulative=False, density=1)
# Out:
# array([[<AxesSubplot:title={'center':'s_rt'}>]], dtype=object)

# %%
df_new.hist(column = 'rt', bins=np.arange(400,3000), cumulative=False, density=1)
# Out:
# array([[<AxesSubplot:title={'center':'rt'}>]], dtype=object)

# %%
#######

# %%
df = df_new

# %%
df_new = df.loc[df.old == False]
tar_far = df_new.yes.mean()
tar_far
# Out:
# 0.18440818944156714

# %%
df_new
# Out:
#               rt  subject_ID       item  lag       category  confidence  \
# 57307   1514.875           0    CHICKEN    0  Uncategorized         1.0
# 57766    853.505           0  BLUEBERRY    0  Uncategorized         1.0
# 58224    731.040           0        BUS    0  Uncategorized         1.0
# 58695    848.955           0      LEMON    0  Uncategorized         1.0
# 59159    643.880           0     OYSTER    0  Uncategorized         1.0
# ...          ...         ...        ...  ...            ...         ...
# 331613  1612.000         656        RUM    0      Beverages         2.0
# 332252       NaN         656       WINE    0      Beverages         NaN
# 332458   401.000         656       MILK    0      Beverages         2.0
# 333257  1308.000         656        TEA    0      Beverages         2.0
# 333652  1517.000         656     COFFEE    0      Beverages         2.0
#
#        category_label  position    old   yes  curr_cat_length  \
# 57307     FarmAnimals         0  False     0              NaN
# 57766           Fruit         1  False     0              NaN
# 58224        Vehicles         2  False     0              NaN
# 58695           Fruit         3  False     0              NaN
# 59159    OceanAnimals         4  False     0              NaN
# ...               ...       ...    ...   ...              ...
# 331613      Beverages       545  False     0              8.0
# 332252      Beverages       548  False  <NA>             10.0
# 332458      Beverages       549  False     0             11.0
# 333257      Beverages       553  False     0             13.0
# 333652      Beverages       555  False     0             14.0
#
#         curr_cat_label_length  itemno  session
# 57307                       0      53        0
# 57766                       0      26        0
# 58224                       0      33        0
# 58695                       1     151        0
# 59159                       0     187        0
# ...                       ...     ...      ...
# 331613                      8     226      350
# 332252                     10     297      350
# 332458                     11     166      350
# 333257                     13     265      350
# 333652                     14      59      350
#
# [105300 rows x 14 columns]

# %%
c = 0.37
csim_new = df_new.csim.to_numpy()
far = np.sum(csim_new > c) / len(csim_new)
far
# Out:
# 0.6551661918328585

# %%
df_old = df.loc[df.old == True]
tar_hr = df_old.yes.mean()
tar_hr
# Out:
# 0.798651476400837

# %%
csim_old = df_old.csim.to_numpy()
hr = np.sum(csim_old > c) / len(csim_old)
hr
# Out:
# 0.9273707773707773
