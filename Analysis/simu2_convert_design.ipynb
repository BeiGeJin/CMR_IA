# %%
import numpy as np
import pandas as pd
import pickle

# %%
df = pd.read_table("../Data/RN2_Pix.dat", sep="\s+", names=['subject','session','list','recog_pos','picture','category','study_pos','old_lag','study_lag','confidence','rt'])
df
# Out:
#        subject  session  list  recog_pos   picture category  study_pos  \
# 0          103        1     0          1     VA084    _OLD_          6
# 1          103        1     0          2   GBEN253    _OLD_          5
# 2          103        1     0          3   ONTO011    _OLD_          3
# 3          103        1     0          4     ISBO1    _NEW_        -99
# 4          103        1     0          5  PAGETT11    _OLD_         38
# ...        ...      ...   ...        ...       ...      ...        ...
# 69883       99        1     5        124    CHN639    _NEW_        -99
# 69884       99        1     5        125     CT173    _OLD_         39
# 69885       99        1     5        126     GRTO2    _NEW_        -99
# 69886       99        1     5        127     GR022    _OLD_         46
# 69887       99        1     5        128   VNDPGCC    _OLD_         44
#
#        old_lag  study_lag  confidence    rt
# 0         -999         59           6   705
# 1           -1         61           6   936
# 2           -2         64           6   678
# 3         -999      -9999           4  1461
# 4         -999         31           5  1799
# ...        ...        ...         ...   ...
# 69883     -999      -9999           4  1460
# 69884     -999        150           2  1040
# 69885     -999      -9999           2  1269
# 69886     -999        145           1   887
# 69887       -2        148           2  1154
#
# [69888 rows x 11 columns]

# %%
# pic to itemno & old
pics = np.unique(df.picture)
pic2itemno = {}
for i in range(len(pics)):
    pic2itemno[pics[i]] = i + 1

itemnos = []
for pic in df.picture:
    itemnos.append(pic2itemno[pic])

df['itemno'] = itemnos
df['old'] = df.category == '_OLD_'

# %%
# unique list index
subjectlist = np.sort(np.unique(df.subject))
df['list_uni'] = df.apply(lambda x: np.where(subjectlist == x['subject'])[0].item()*6 + x['list'], axis =1)
df = df.sort_values(by = ['list_uni','recog_pos'])
df
# Out:
#        subject  session  list  recog_pos   picture category  study_pos  \
# 36096       37        1     0          1    CHN211    _OLD_          9
# 36097       37        1     0          2   GBEN655    _OLD_         55
# 36098       37        1     0          3    ECU104    _OLD_         52
# 36099       37        1     0          4    MXACP4    _OLD_         47
# 36100       37        1     0          5    CHN118    _NEW_        -99
# ...        ...      ...   ...        ...       ...      ...        ...
# 36091      172        1     5        124  JEROCTWL    _NEW_        -99
# 36092      172        1     5        125    THA064    _NEW_        -99
# 36093      172        1     5        126     RI003    _OLD_         28
# 36094      172        1     5        127    IND117    _NEW_        -99
# 36095      172        1     5        128    HIO042    _NEW_        -99
#
#        old_lag  study_lag  confidence    rt  itemno    old  list_uni
# 36096     -999         56           6  1053     195   True         0
# 36097       46         11           2  2306     493   True         0
# 36098       -3         15           3  1457     376   True         0
# 36099       -5         21           1  2333     998   True         0
# 36100     -999      -9999           1  1704     184  False         0
# ...        ...        ...         ...   ...     ...    ...       ...
# 36091     -999      -9999           2  1076     801  False       545
# 36092     -999      -9999           6   808    1335  False       545
# 36093     -999        162           4   999    1245   True       545
# 36094     -999      -9999           2  1114     747  False       545
# 36095     -999      -9999           2   923     640  False       545
#
# [69888 rows x 14 columns]

# %%
# organize
df = df.drop(columns=['session','picture','category','confidence','rt','subject','list'])
df = df[['list_uni','recog_pos', 'itemno', 'old', 'old_lag', 'study_pos', 'study_lag']]
df
# Out:
#        list_uni  recog_pos  itemno    old  old_lag  study_pos  study_lag
# 36096         0          1     195   True     -999          9         56
# 36097         0          2     493   True       46         55         11
# 36098         0          3     376   True       -3         52         15
# 36099         0          4     998   True       -5         47         21
# 36100         0          5     184  False     -999        -99      -9999
# ...         ...        ...     ...    ...      ...        ...        ...
# 36091       545        124     801  False     -999        -99      -9999
# 36092       545        125    1335  False     -999        -99      -9999
# 36093       545        126    1245   True     -999         28        162
# 36094       545        127     747  False     -999        -99      -9999
# 36095       545        128     640  False     -999        -99      -9999
#
# [69888 rows x 7 columns]

# %% [markdown]
# ### design

# %%
rng = np.random.default_rng(seed=42)
simu_sess_num = 1000
simu_old_num = 64
simu_new_num = 64

list_unique = np.unique(df.list_uni)
sess = rng.choice(list_unique, simu_sess_num)
sess
# Out:
# array([ 48, 422, 357, 239, 236, 468,  46, 380, 110,  51, 287, 532, 401,
#        415, 391, 429, 280,  69, 458, 245, 273, 202,  99, 506, 426, 351,
#        219, 449, 297, 242, 245, 124,  50, 302, 484,  34, 468, 451, 151,
#        344,  90, 413, 382, 193,  37, 530, 243, 487, 370, 424, 414, 106,
#        198, 254, 271,  23, 298,  84, 405, 372, 503, 406, 200, 528, 224,
#        177, 494, 202,  41, 256, 434, 103, 252,  70, 374, 259, 180, 123,
#        308, 365, 513, 238,  87, 454, 343, 382,  53, 170, 419, 454, 237,
#        439, 459, 211, 490, 157, 130, 372, 347,  76, 454, 109, 439,   4,
#        435, 429, 426, 363, 257, 385, 151, 426, 303, 250, 276, 310,  20,
#         76, 134,  62, 240, 364, 357, 257, 466, 308,  43, 417, 313, 346,
#        308, 302,  49, 305, 434, 165, 329,  16, 189, 238, 536, 117, 150,
#        223, 541, 465,  18, 127, 448,  31, 467, 153, 501, 160, 237, 361,
#         68, 304, 275, 428, 543, 362, 223, 221, 228, 444, 175,  91, 182,
#         12,  57,  49, 421, 394, 380, 252, 391,  88, 491, 273, 512,  83,
#        271, 380, 270, 243,  90, 208, 130, 164, 373, 344, 331, 197, 523,
#         47, 187,  64, 185, 525, 199, 496, 270, 382, 249, 145, 417, 529,
#        143, 425, 142, 391, 430, 245, 402, 148,  43,  52, 244, 492,  69,
#        248, 384, 110, 394, 167, 441, 316, 298,  96, 252, 467,  10, 414,
#        269, 392, 362, 235, 168, 342,  76, 318,  51, 354, 343,  46, 413,
#        227, 429,  22,  97, 269, 102, 180, 360,  78, 370,  56,  95, 320,
#        433,  93, 163, 505, 540, 317, 244, 189, 334, 322, 160,  12,  82,
#        523, 228, 263, 255, 427,  35,  45, 150, 265, 366, 267, 240, 512,
#         87, 312, 296, 258, 440, 145, 520, 181, 297, 284, 463, 239, 155,
#         11, 198, 451,   5, 489, 296,  76, 164, 302, 172,  59, 363, 367,
#         64, 153, 133, 360, 398, 396, 512, 419, 175,  58, 335, 500, 532,
#        297,  60, 213, 544,  24, 480, 373, 155, 424, 456,  23,  58, 363,
#        545,  13, 363,  74, 354, 340,  49, 371, 489, 471,  15, 134, 131,
#        247,  78, 466, 424, 441, 108,   7, 497, 157, 358, 496,  19,   2,
#          2,  85,  28, 447, 330, 535, 437, 525, 130, 157, 463, 133,  31,
#        365, 437, 528, 506,  65, 421, 461, 381, 447, 457, 243,  21, 249,
#        110,  62,  68, 380, 275, 294, 406, 299, 343,  46, 464, 245,  84,
#        444, 401,  28, 105,   8, 147,  54, 387, 285, 535, 409, 333, 278,
#         29,  38, 336,   2,  23, 119, 482, 250, 387, 224,  94, 202,  50,
#        420, 100, 205, 535, 323, 250, 296, 428, 138, 347, 476, 312, 243,
#         79, 135, 516, 295, 164, 228, 315, 293, 382, 140, 354, 241, 513,
#         86,  81, 252, 277, 377, 220, 498, 258,  70,  65, 531,  73, 517,
#        151,  51, 166, 335, 233, 428, 333, 218, 346, 530, 224,  83, 223,
#        458, 118, 518, 321, 328, 173, 502,  19, 163, 228, 260, 258,  80,
#        123,  52, 312, 191, 308, 321, 383, 298, 353, 320, 356, 336, 172,
#        134, 429, 187, 299, 107, 235, 289, 341, 287, 196, 525, 279])

# %%
df_study = pd.DataFrame()
df_test = pd.DataFrame()

for i in range(len(sess)):
    tmp = df.loc[df.list_uni == sess[i]]
    tmp["session"] = i
    
    df_test = df_test.append(tmp)
    
    tmp_study = tmp.loc[tmp.old == True]
    tmp_study = tmp_study.sort_values(by = "study_pos")
    df_study = df_study.append(tmp_study)
    
df_study.reset_index(drop = True, inplace = True)
df_test.reset_index(drop = True, inplace = True)
# Out:
# /home1/beigejin/.conda/envs/jinbeige/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_study = df_study.drop(columns=['recog_pos', 'old', 'old_lag','study_lag'])
df_study
# Out:
#        list_uni  itemno  study_pos  session
# 0            48    1328          1        0
# 1            48     768          2        0
# 2            48     518          3        0
# 3            48      21          4        0
# 4            48     914          5        0
# ...         ...     ...        ...      ...
# 63995       279     801         60      999
# 63996       279     997         61      999
# 63997       279    1186         62      999
# 63998       279    1279         63      999
# 63999       279    1475         64      999
#
# [64000 rows x 4 columns]

# %%
df_test
# Out:
#         list_uni  recog_pos  itemno    old  old_lag  study_pos  study_lag  \
# 0             48          1     490   True     -999         52         13
# 1             48          2     541   True        9         61          5
# 2             48          3    1066  False     -999        -99      -9999
# 3             48          4     942   True     -999         34         34
# 4             48          5    1464  False     -999        -99      -9999
# ...          ...        ...     ...    ...      ...        ...        ...
# 127995       279        124     530   True       -4         26        162
# 127996       279        125     357  False     -999        -99      -9999
# 127997       279        126     307  False     -999        -99      -9999
# 127998       279        127    1349  False     -999        -99      -9999
# 127999       279        128     914   True     -999         40        152
#
#         session
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 127995      999
# 127996      999
# 127997      999
# 127998      999
# 127999      999
#
# [128000 rows x 8 columns]

# %%
with open('../Data/simu2_design.pkl', 'wb') as outp:
    pickle.dump(df_study, outp, pickle.HIGHEST_PROTOCOL)
    pickle.dump(df_test, outp, pickle.HIGHEST_PROTOCOL)
