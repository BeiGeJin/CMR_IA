# %%
import numpy as np
import pickle
import math
from scipy.stats import sem
import matplotlib.pyplot as plt
import pandas as pd
import time
import pprint
import seaborn as sns
import statsmodels.formula.api as smf
import CMR_IA as cmr
sns.set_context('paper')
pd.set_option('display.max_columns', None)

# %%
with open("../Data/simu4_design.pkl", 'rb') as inp:
    df_study = pickle.load(inp)
    df_test = pickle.load(inp)

# %%
# df_study = df_study.loc[df_study.session < 5]
df_study
# Out:
#        itemno        item  freq  quantile  session
# 0         552        FARM  1161         8        0
# 1         812     LEOPARD   118         3        0
# 2         741  INSTRUCTOR    78         2        0
# 3         153      BOTTLE  1479         8        0
# 4         150        BOOT   149         3        0
# ...       ...         ...   ...       ...      ...
# 99995    1491        TOWN  3328         9      999
# 99996    1057       PIANO   466         6      999
# 99997    1398   SUBMARINE   154         3      999
# 99998     791   LABYRINTH    32         0      999
# 99999    1596        WAVE   715         7      999
#
# [100000 rows x 5 columns]

# %%
# df_test = df_test.loc[df_test.session < 200]
df_test
# Out:
#         itemno     item  freq  quantile  session    old
# 0          595     FORT   411         6        0   True
# 1          864  MANSION   156         3        0   True
# 2          121    BENCH   345         6        0   True
# 3          667    GUARD   658         7        0  False
# 4          112      BEE   185         4        0   True
# ...        ...      ...   ...       ...      ...    ...
# 199995     850     LUNG   169         4      999   True
# 199996    1485  TORNADO    34         0      999  False
# 199997    1553  VEHICLE   383         6      999  False
# 199998    1215      RUG   321         5      999   True
# 199999    1228   SALOON   181         4      999   True
#
# [200000 rows x 6 columns]

# %% [markdown]
# ### Run CMR-IA

# %%
s_mat = np.loadtxt('../Data/wordpools/w2v.txt')

# %%
params = cmr.make_default_params()
params.update(
    beta_enc = 0.635,
    beta_rec = 0.5,
    beta_rec_post = 0.888,
    gamma_fc = 0.432,
    s_fc = 0.423,
    c_thresh = 0.577,
    a = 2800,
    b = 2.14
)
params
# Out:
# {'beta_enc': 0.635,
#  'beta_rec': 0.5,
#  'beta_rec_post': 0.888,
#  'beta_distract': None,
#  'phi_s': 2,
#  'phi_d': 0.5,
#  's_cf': 0,
#  's_fc': 0.423,
#  'kappa': 0.5,
#  'eta': 0.5,
#  'omega': 8,
#  'alpha': 4,
#  'c_thresh': 0.577,
#  'lamb': 0.5,
#  'rec_time_limit': 60000.0,
#  'dt': 10,
#  'nitems_in_accumulator': 50,
#  'max_recalls': 50,
#  'learn_while_retrieving': False,
#  'a': 2800,
#  'b': 2.14,
#  'gamma_fc': 0.432,
#  'gamma_cf': 0.5}

# %%
df_simu = cmr.run_norm_recog_multi_sess(params,df_study,df_test,s_mat)
df_simu
# Out:
# CMR Time: 47.711525440216064
#         session  itemno  s_resp         s_rt      csim
# 0             0     595     0.0  1415.115356  0.258118
# 1             0     864     0.0  2554.847168  0.534184
# 2             0     121     0.0  2423.887207  0.509595
# 3             0     667     0.0  2010.428223  0.422200
# 4             0     112     0.0  2730.358154  0.565231
# ...         ...     ...     ...          ...       ...
# 199995      999     850     1.0  2627.942871  0.606635
# 199996      999    1485     0.0  2178.174561  0.459648
# 199997      999    1553     0.0  2666.063965  0.554095
# 199998      999    1215     1.0  2633.304443  0.605682
# 199999      999    1228     1.0  2152.654785  0.699859
#
# [200000 rows x 5 columns]

# %%
df_simu = df_simu.merge(df_test,on=['session','itemno'])
df_simu
# Out:
#         session  itemno  s_resp         s_rt      csim     item  freq  \
# 0             0     595     0.0  1415.115356  0.258118     FORT   411
# 1             0     864     0.0  2554.847168  0.534184  MANSION   156
# 2             0     121     0.0  2423.887207  0.509595    BENCH   345
# 3             0     667     0.0  2010.428223  0.422200    GUARD   658
# 4             0     112     0.0  2730.358154  0.565231      BEE   185
# ...         ...     ...     ...          ...       ...      ...   ...
# 199995      999     850     1.0  2627.942871  0.606635     LUNG   169
# 199996      999    1485     0.0  2178.174561  0.459648  TORNADO    34
# 199997      999    1553     0.0  2666.063965  0.554095  VEHICLE   383
# 199998      999    1215     1.0  2633.304443  0.605682      RUG   321
# 199999      999    1228     1.0  2152.654785  0.699859   SALOON   181
#
#         quantile    old
# 0              6   True
# 1              3   True
# 2              6   True
# 3              7  False
# 4              4   True
# ...          ...    ...
# 199995         4   True
# 199996         0  False
# 199997         6  False
# 199998         5   True
# 199999         4   True
#
# [200000 rows x 9 columns]

# %%
df_simu.groupby(['old']).s_resp.mean()
# Out:
# old
# False    0.19074
# True     0.84156
# Name: s_resp, dtype: float64

# %% [markdown]
# ### WFE

# %%
# get wordfreq quantile
with open('../Data/simu4_word_freq.pkl', 'rb') as inp:
    df = pickle.load(inp)
df
# Out:
#           item  itemno  freq  quantile
# 0      ABDOMEN       1   110         2
# 1      ACROBAT       4    17         0
# 2        ADULT       8   906         8
# 3        ALLEY      15   165         3
# 4    ALLIGATOR      16    12         0
# ..         ...     ...   ...       ...
# 979       YOKE    1632    12         0
# 980       YOLK    1633    47         1
# 981      YOUTH    1634  1159         8
# 982     ZIPPER    1636    24         0
# 983        ZOO    1637   156         3
#
# [984 rows x 4 columns]

# %%
item2q = df[["itemno","quantile"]].set_index("itemno").to_dict()['quantile']
create_level = {0:"new lf", 1:"new hf", 2:"old lf", 3:"old hf"}

df_simu['quantile'] = df_simu.apply(lambda x: item2q[x["itemno"]], axis=1)
df_simu['hf'] = df_simu['quantile'] >= 5
df_simu['level'] = df_simu.apply(lambda x: create_level[x['old'] * 2 + x['hf']], axis = 1)
df_simu
# Out:
#         session  itemno  s_resp         s_rt      csim     item  freq  \
# 0             0     595     0.0  1415.115356  0.258118     FORT   411
# 1             0     864     0.0  2554.847168  0.534184  MANSION   156
# 2             0     121     0.0  2423.887207  0.509595    BENCH   345
# 3             0     667     0.0  2010.428223  0.422200    GUARD   658
# 4             0     112     0.0  2730.358154  0.565231      BEE   185
# ...         ...     ...     ...          ...       ...      ...   ...
# 199995      999     850     1.0  2627.942871  0.606635     LUNG   169
# 199996      999    1485     0.0  2178.174561  0.459648  TORNADO    34
# 199997      999    1553     0.0  2666.063965  0.554095  VEHICLE   383
# 199998      999    1215     1.0  2633.304443  0.605682      RUG   321
# 199999      999    1228     1.0  2152.654785  0.699859   SALOON   181
#
#         quantile    old     hf   level
# 0              6   True   True  old hf
# 1              3   True  False  old lf
# 2              6   True   True  old hf
# 3              7  False   True  new hf
# 4              4   True  False  old lf
# ...          ...    ...    ...     ...
# 199995         4   True  False  old lf
# 199996         0  False  False  new lf
# 199997         6  False   True  new hf
# 199998         5   True   True  old hf
# 199999         4   True  False  old lf
#
# [200000 rows x 11 columns]

# %%
df_itemgp = pd.pivot_table(df_simu, values='s_resp', index=['itemno'],
                    columns=['old'],aggfunc = np.mean)
df_itemgp.columns = ['far','hr']
df_itemgp = df_itemgp.reset_index()
df_itemgp
# Out:
#      itemno       far        hr
# 0         1  0.175824  0.943820
# 1         4  0.000000  0.776596
# 2         8  0.000000  0.808696
# 3        15  0.072072  0.970588
# 4        16  0.689320  0.976190
# ..      ...       ...       ...
# 979    1632  0.037736  0.953271
# 980    1633  0.641509  0.990196
# 981    1634  0.000000  0.567010
# 982    1636  0.379630  0.990741
# 983    1637  0.072289  0.875000
#
# [984 rows x 3 columns]

# %%
df_itemgp = df_itemgp.merge(df,on=['itemno'])
df_itemgp
# Out:
#      itemno       far        hr       item  freq  quantile
# 0         1  0.175824  0.943820    ABDOMEN   110         2
# 1         4  0.000000  0.776596    ACROBAT    17         0
# 2         8  0.000000  0.808696      ADULT   906         8
# 3        15  0.072072  0.970588      ALLEY   165         3
# 4        16  0.689320  0.976190  ALLIGATOR    12         0
# ..      ...       ...       ...        ...   ...       ...
# 979    1632  0.037736  0.953271       YOKE    12         0
# 980    1633  0.641509  0.990196       YOLK    47         1
# 981    1634  0.000000  0.567010      YOUTH  1159         8
# 982    1636  0.379630  0.990741     ZIPPER    24         0
# 983    1637  0.072289  0.875000        ZOO   156         3
#
# [984 rows x 6 columns]

# %%
df_quantgp = df_itemgp.groupby(['quantile']).agg({'hr': 'mean', 'far': 'mean'}).reset_index()
df_quantgp
# Out:
#    quantile        hr       far
# 0         0  0.913146  0.252380
# 1         1  0.895176  0.324268
# 2         2  0.879981  0.243523
# 3         3  0.872789  0.175444
# 4         4  0.864909  0.211061
# 5         5  0.820420  0.206035
# 6         6  0.830834  0.155847
# 7         7  0.815802  0.139433
# 8         8  0.745439  0.119575
# 9         9  0.771942  0.084204

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True,figsize=(5,10))
fig.subplots_adjust(hspace=0.03)

sns.pointplot(data=df_quantgp, y='hr', x='quantile', ax=ax1, marker = 'o', color = 'r')
sns.pointplot(data=df_quantgp, y='far', x='quantile', ax=ax2, marker = 'o', color = 'g')

ax1.set_ylim(0.62, 1)
ax1.set_yticks(np.arange(0.65,1.01,0.05))
ax2.set_ylim(0.05, 0.43)
ax2.set_yticks(np.arange(0,0.45,0.05))
# plt.xscale('log')
# plt.xlim(5, 14000)

ax1.spines.bottom.set_visible(False)
ax1.spines.top.set_visible(False)
ax2.spines.top.set_visible(False)
ax1.spines.right.set_visible(False)
ax2.spines.right.set_visible(False)
ax1.tick_params(
    axis='x',
    which='both',
    bottom=False,
    top=False, 
    labelbottom=False,
    labeltop=False) 
ax2.minorticks_off()

d = .5  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax1.plot(0,0, transform=ax1.transAxes, **kwargs)
ax2.plot(0,1, transform=ax2.transAxes, **kwargs)

ax1.set_ylabel('hit rate')
ax1.set_xlabel(None)
ax2.set_ylabel('false alarm rate')
ax2.set_xlabel('word frequency')

plt.savefig('fig/simu4_WFE.pdf')
plt.show()

# %% [markdown]
# ### Analysis

# %%
sns.histplot(data=df_simu, x="csim", hue = "level", hue_order = ["new hf", "new lf", "old hf", "old lf"], palette = [[0,0,1],[0.5,0.5,1],[1,0,0],[1,0.5,0.5]], stat = "probability", common_norm=False, edgecolor = None)
plt.savefig('fig/simu4_csim.pdf')

# %%
freq_order = df.sort_values(by="freq")['itemno'].to_numpy()

# %%
n = len(df)
smat_order = np.zeros((n,n))
for i in range(n):
    for j in range(n):
        smat_order[i,j] = s_mat[freq_order[i],freq_order[j]]

# %%
smat_order
# Out:
# array([[ 1.        ,  0.2011113 ,  0.13239495, ..., -0.01074924,
#          0.03020283,  0.21313739],
#        [ 0.2011113 ,  1.        ,  0.08911801, ..., -0.0675719 ,
#          0.08618007,  0.12869283],
#        [ 0.13239495,  0.08911801,  1.        , ..., -0.01855728,
#          0.10520838,  0.10746981],
#        ...,
#        [-0.01074924, -0.0675719 , -0.01855728, ...,  1.        ,
#          0.09575007,  0.01251824],
#        [ 0.03020283,  0.08618007,  0.10520838, ...,  0.09575007,
#          1.        ,  0.14337983],
#        [ 0.21313739,  0.12869283,  0.10746981, ...,  0.01251824,
#          0.14337983,  1.        ]])

# %%
# plt.subplots(figsize=(20,20))
# sns.heatmap(smat_order,vmax = 0.5, vmin = 0, cmap = 'Reds')
# plt.xlabel('freq order')
# plt.ylabel('freq order')
# plt.title("association matrix of words in freq order")
# plt.savefig('fig/simu4_smat.pdf')
# plt.show()

# %%
df.groupby("quantile").count()
# Out:
#           item  itemno  freq
# quantile
# 0          100     100   100
# 1           97      97    97
# 2           98      98    98
# 3          102     102   102
# 4           95      95    95
# 5           98      98    98
# 6          101     101   101
# 7           96      96    96
# 8           98      98    98
# 9           99      99    99

# %%
np.sum(smat_order[0:100,0:100])
# Out:
# 1100.5559062622006

# %%
np.mean(smat_order[0:100,0:100])
# Out:
# 0.11005559062622006

# %%
np.std(smat_order[0:100,0:100])
# Out:
# 0.123877820596972

# %%
np.sum(smat_order[-100:-1,-100:-1])
# Out:
# 1030.4704505293234

# %%
np.mean(smat_order[-100:-1,-100:-1])
# Out:
# 0.10513931747059722

# %%
np.std(smat_order[-100:-1,-100:-1])
# Out:
# 0.12517490038419882

# %%
np.mean(smat_order[0:100,-100:-1])
# Out:
# 0.09739985647380661

# %%
np.mean(smat_order[0:100,:])
# Out:
# 0.10552878680397054

# %%
np.mean(smat_order[-100:-1,:])
# Out:
# 0.1024252909540282
