# %%
import numpy as np
import pickle
import math
import matplotlib.pyplot as plt
import pandas as pd
import time
import pprint
import seaborn as sns
import CMR_IA as cmr
sns.set_context('paper')
# pd.set_option('display.max_columns', None)

# %%
with open("../Data/simu6b_design.pkl", 'rb') as inp:
    df_study = pickle.load(inp)
    df_test = pickle.load(inp)
# df_study = df_study.loc[df_study.session < 500]
# df_test = df_test.loc[df_test.session < 500]

# %%
df_study
# Out:
#        study_itemno1  study_itemno2 study_item1 study_item2  session
# 0                140            838   BLUEBERRY        LOCK        0
# 1               1587           1240    WARDROBE   SAXOPHONE        0
# 2               1132            702      PROTON      HELMET        0
# 3                299           1282       CHILD     SHELTER        0
# 4               1391           1059  STRAWBERRY      PICKLE        0
# ...              ...            ...         ...         ...      ...
# 11995            301           1184     CHIMNEY      REPORT      999
# 11996             57            965      ATTIRE         NUT      999
# 11997            155           1112     BOULDER      POSSUM      999
# 11998            106           1368        BEAR       STAKE      999
# 11999            222            869        CALF      MARINE      999
#
# [12000 rows x 5 columns]

# %%
df_test
# Out:
#        test_itemno1  test_itemno2 test_item  correct_ans  order  rep  test  \
# 0               210            -1   CABBAGE          327      1    1     1
# 1              1251            -1    SCOTCH          819      2    1     1
# 2               145            -1      BODY         1198      1    1     1
# 3              1059            -1    PICKLE         1391      2    1     1
# 4               711            -1       HOE         1519      1    1     1
# ...             ...           ...       ...          ...    ...  ...   ...
# 23995           965            -1       NUT           57      2    1     2
# 23996          1075            -1    PISTOL          644      2    1     2
# 23997          1090            -1      PLUM         1609      2    1     2
# 23998          1184            -1    REPORT          301      2    1     2
# 23999           869            -1    MARINE          222      2    1     2
#
#        session  test_pos  pair_idx
# 0            0         1        11
# 1            0         2         8
# 2            0         3         7
# 3            0         4         5
# 4            0         5         9
# ...        ...       ...       ...
# 23995      999        20     11997
# 23996      999        21     11993
# 23997      999        22     11991
# 23998      999        23     11996
# 23999      999        24     12000
#
# [24000 rows x 10 columns]

# %% [markdown]
# ### Run CMR-IA

# %%
s_mat = np.load('../Data/wordpools/ltp_FR_similarity_matrix.npy')

# %%
params = cmr.make_default_params()
params.update(
    beta_enc = 0.5,
    beta_rec = 0.1, # beta for retrieved item
    beta_cue = 0.45, # beta for cue
    beta_distract = 0.1,
    gamma_fc = 0.35,
    gamma_cf = 0.35,
    s_fc = 0.1,
    s_cf = 0.1,
    c_thresh = 0.64,
    c_thresh_ass = 0.01,
    kappa = 0.02,
    lamb = 0.01,
    eta = 0.005,
    phi_s = 1,
    phi_d = 0.6,
    nitems_in_accumulator = 24,
    d_ass = 0.7,
    learn_while_retrieving = True,
    omega = 5,
    alpha = 1
)
params
# Out:
# {'beta_enc': 0.5,
#  'beta_rec': 0.1,
#  'beta_cue': 0.45,
#  'beta_rec_post': 0.5,
#  'beta_distract': 0.1,
#  'phi_s': 1,
#  'phi_d': 0.6,
#  's_cf': 0.1,
#  's_fc': 0.1,
#  'kappa': 0.02,
#  'eta': 0.005,
#  'omega': 5,
#  'alpha': 1,
#  'c_thresh': 0.64,
#  'c_thresh_ass': 0.01,
#  'd_ass': 0.7,
#  'lamb': 0.01,
#  'rec_time_limit': 60000.0,
#  'dt': 10,
#  'nitems_in_accumulator': 24,
#  'max_recalls': 50,
#  'learn_while_retrieving': True,
#  'a': 2800,
#  'b': 20,
#  'm': 0,
#  'n': 1,
#  'c1': 0,
#  'No_recall': None,
#  'var_enc': 1,
#  'bad_enc_ratio': 1,
#  'gamma_fc': 0.35,
#  'gamma_cf': 0.35}

# %%
df_simu, f_in, f_dif = cmr.run_success_multi_sess(params, df_study, df_test, s_mat, mode='CR-CR')
df_simu['test_pos'] = np.tile(np.arange(1,25),1000)
df_simu
# Out:
# CMR2 Time: 27.582019329071045
#        session  test_itemno1  test_itemno2  s_resp    s_rt      csim  test_pos
# 0            0           210            -1   327.0  1830.0  0.797872         1
# 1            0          1251            -1    -2.0    -2.0  0.627754         2
# 2            0           145            -1    -2.0    -2.0  0.554538         3
# 3            0          1059            -1    -2.0    -2.0  0.638699         4
# 4            0           711            -1  1198.0  2360.0  0.641787         5
# ...        ...           ...           ...     ...     ...       ...       ...
# 23995      999           965            -1    57.0  1250.0  0.817659        20
# 23996      999          1075            -1   644.0  1010.0  0.845879        21
# 23997      999          1090            -1    -2.0    -2.0  0.544596        22
# 23998      999          1184            -1   301.0  1150.0  0.859984        23
# 23999      999           869            -1    -1.0    -1.0 -1.000000        24
#
# [24000 rows x 7 columns]

# %%
df_simu = df_simu.merge(df_test,on=['session','test_itemno1','test_itemno2', 'test_pos'])
df_simu['correct'] = df_simu.s_resp == df_simu.correct_ans
df_simu
# Out:
#        session  test_itemno1  test_itemno2  s_resp    s_rt      csim  \
# 0            0           210            -1   327.0  1830.0  0.797872
# 1            0          1251            -1    -2.0    -2.0  0.627754
# 2            0           145            -1    -2.0    -2.0  0.554538
# 3            0          1059            -1    -2.0    -2.0  0.638699
# 4            0           711            -1  1198.0  2360.0  0.641787
# ...        ...           ...           ...     ...     ...       ...
# 23995      999           965            -1    57.0  1250.0  0.817659
# 23996      999          1075            -1   644.0  1010.0  0.845879
# 23997      999          1090            -1    -2.0    -2.0  0.544596
# 23998      999          1184            -1   301.0  1150.0  0.859984
# 23999      999           869            -1    -1.0    -1.0 -1.000000
#
#        test_pos test_item  correct_ans  order  rep  test  pair_idx  correct
# 0             1   CABBAGE          327      1    1     1        11     True
# 1             2    SCOTCH          819      2    1     1         8    False
# 2             3      BODY         1198      1    1     1         7    False
# 3             4    PICKLE         1391      2    1     1         5    False
# 4             5       HOE         1519      1    1     1         9    False
# ...         ...       ...          ...    ...  ...   ...       ...      ...
# 23995        20       NUT           57      2    1     2     11997     True
# 23996        21    PISTOL          644      2    1     2     11993     True
# 23997        22      PLUM         1609      2    1     2     11991    False
# 23998        23    REPORT          301      2    1     2     11996     True
# 23999        24    MARINE          222      2    1     2     12000    False
#
# [24000 rows x 14 columns]

# %%
df_cond = df_simu.groupby(["pair_idx","test"])['order'].mean().to_frame(name='corr_rate').reset_index()
df_cond = df_cond.pivot_table(index='pair_idx',columns='test',values='corr_rate').reset_index()
df_cond.columns = ['pair_idx','test1','test2']
def cond(x):
    test1 = x['test1']
    test2 = x['test2']
    if test1 == 1 and test2 == 1:
        return 'F-F'
    elif test1 == 1 and test2 == 2:
        return 'F-B'
    elif test1 == 2 and test2 == 1:
        return 'B-F'
    elif test1 == 2 and test2 == 2:
        return 'B-B'

df_cond['cond'] = df_cond.apply(lambda x:cond(x),axis=1)
df_cond['cong'] = df_cond.apply(lambda x: 'Identical' if x['cond'] == 'F-F' or x['cond'] == 'B-B' else 'Reversed',axis=1)
df_cond
# Out:
#        pair_idx  test1  test2 cond       cong
# 0             1    2.0    1.0  B-F   Reversed
# 1             2    1.0    2.0  F-B   Reversed
# 2             3    2.0    1.0  B-F   Reversed
# 3             4    1.0    1.0  F-F  Identical
# 4             5    2.0    2.0  B-B  Identical
# ...         ...    ...    ...  ...        ...
# 11995     11996    2.0    2.0  B-B  Identical
# 11996     11997    1.0    2.0  F-B   Reversed
# 11997     11998    2.0    1.0  B-F   Reversed
# 11998     11999    1.0    1.0  F-F  Identical
# 11999     12000    1.0    2.0  F-B   Reversed
#
# [12000 rows x 5 columns]

# %%
pairidx2cond = df_cond.loc[:,['pair_idx','cond']].set_index("pair_idx").to_dict()['cond']
pairidx2cong = df_cond.loc[:,['pair_idx','cong']].set_index("pair_idx").to_dict()['cong']
df_simu['cond'] = df_simu.apply(lambda x:pairidx2cond[x['pair_idx']],axis=1)
df_simu['cong'] = df_simu.apply(lambda x:pairidx2cong[x['pair_idx']],axis=1)
df_simu.head(24)
# Out:
#     session  test_itemno1  test_itemno2  s_resp    s_rt      csim  test_pos  \
# 0         0           210            -1   327.0  1830.0  0.797872         1
# 1         0          1251            -1    -2.0    -2.0  0.627754         2
# 2         0           145            -1    -2.0    -2.0  0.554538         3
# 3         0          1059            -1    -2.0    -2.0  0.638699         4
# 4         0           711            -1  1198.0  2360.0  0.641787         5
# 5         0           838            -1    -2.0    -2.0  0.527408         6
# 6         0           153            -1    -2.0    -2.0  0.596206         7
# 7         0          1587            -1    -2.0    -2.0  0.575857         8
# 8         0           856            -1    -2.0    -2.0  0.545230         9
# 9         0           702            -1    -2.0    -2.0  0.572660        10
# 10        0           299            -1  1282.0  1980.0  0.650683        11
# 11        0          1372            -1    -2.0    -2.0  0.500791        12
# 12        0           140            -1   299.0  1270.0  0.677518        13
# 13        0           145            -1  1282.0  1180.0  0.668000        14
# 14        0          1169            -1    -2.0    -2.0  0.592101        15
# 15        0           299            -1  1198.0  1370.0  0.654077        16
# 16        0          1059            -1    -2.0    -2.0  0.607515        17
# 17        0          1519            -1   711.0  1040.0  0.801356        18
# 18        0           210            -1   327.0  1040.0  0.802707        19
# 19        0          1132            -1    -2.0    -2.0  0.579848        20
# 20        0          1240            -1    -2.0    -2.0  0.618026        21
# 21        0          1251            -1    -2.0    -2.0  0.637831        22
# 22        0           856            -1   819.0  3130.0  0.646000        23
# 23        0           736            -1   153.0  2370.0  0.688346        24
#
#     test_item  correct_ans  order  rep  test  pair_idx  correct cond  \
# 0     CABBAGE          327      1    1     1        11     True  F-F
# 1      SCOTCH          819      2    1     1         8    False  B-B
# 2        BODY         1198      1    1     1         7    False  F-F
# 3      PICKLE         1391      2    1     1         5    False  B-B
# 4         HOE         1519      1    1     1         9    False  F-B
# 5        LOCK          140      2    1     1         1    False  B-F
# 6      BOTTLE          736      1    1     1         6    False  F-B
# 7    WARDROBE         1240      1    1     1         2    False  F-B
# 8        MAID          607      2    1     1        10    False  B-B
# 9      HELMET         1132      2    1     1         3    False  B-F
# 10      CHILD         1282      1    1     1         4     True  F-F
# 11    STAPLER         1169      2    1     1        12    False  B-F
# 12  BLUEBERRY          838      1    1     2         1    False  B-F
# 13       BODY         1198      1    1     2         7    False  F-F
# 14        RAT         1372      1    1     2        12    False  B-F
# 15      CHILD         1282      1    1     2         4    False  F-F
# 16     PICKLE         1391      2    1     2         5    False  B-B
# 17     TUNNEL          711      2    1     2         9     True  F-B
# 18    CABBAGE          327      1    1     2        11     True  F-F
# 19     PROTON          702      1    1     2         3    False  B-F
# 20  SAXOPHONE         1587      2    1     2         2    False  F-B
# 21     SCOTCH          819      2    1     2         8    False  B-B
# 22       MAID          607      2    1     2        10    False  B-B
# 23     INDIAN          153      2    1     2         6     True  F-B
#
#          cong
# 0   Identical
# 1   Identical
# 2   Identical
# 3   Identical
# 4    Reversed
# 5    Reversed
# 6    Reversed
# 7    Reversed
# 8   Identical
# 9    Reversed
# 10  Identical
# 11   Reversed
# 12   Reversed
# 13  Identical
# 14   Reversed
# 15  Identical
# 16  Identical
# 17   Reversed
# 18  Identical
# 19   Reversed
# 20   Reversed
# 21  Identical
# 22  Identical
# 23   Reversed

# %%
len(f_in[0])
# Out:
# 24

# %%
sessions = np.unique(df_simu.session.to_numpy())
tmp_corr_fin = []
tmp_omean_fin = []
tmp_omax_fin = []

for sess in sessions:
    df_tmp = df_study.loc[df_study.session == sess]
    tmp1 = df_tmp.study_itemno1.to_numpy()
    tmp2 = df_tmp.study_itemno2.to_numpy()
    tmp = np.concatenate((tmp1, tmp2))
    tmp = np.sort(tmp)

    df_tmp1 = df_simu.loc[df_simu.session == sess]
    tmp_test = df_tmp1.test_itemno1
    tmp_corr = df_tmp1.correct_ans
    # tmp_test = df_simu.loc[df_simu.session == sess, 'test_itemno']
    # tmp_corr = df_simu.loc[df_simu.session == sess, 'correct_ans']
    testid = np.searchsorted(tmp, tmp_test)
    corrid = np.searchsorted(tmp, tmp_corr)

    fin_sess = f_dif[sess]
    # tmp_corr_fin = []
    # tmp_omean_fin = []
    # tmp_omax_fin = []
    for i in range(len(testid)):
        tmp_corr_fin.append(fin_sess[i][corrid[i]])
        tmp_omean_fin.append(np.mean(np.delete(fin_sess[i], corrid[i])))
        tmp_omax_fin.append(np.delete(fin_sess[i], corrid[i]).max())
    # df_simu.loc[df_simu.session == sess, 'corr_fin']= tmp_corr_fin
    # df_simu.loc[df_simu.session == sess, 'omean_fin'] = tmp_omean_fin
    # df_simu.loc[df_simu.session == sess, 'omax_fin'] = tmp_omax_fin

df_simu['corr_fin']= tmp_corr_fin
df_simu['omean_fin'] = tmp_omean_fin
df_simu['omax_fin'] = tmp_omax_fin
df_simu
# Out:
#        session  test_itemno1  test_itemno2  s_resp    s_rt      csim  \
# 0            0           210            -1   327.0  1830.0  0.797872
# 1            0          1251            -1    -2.0    -2.0  0.627754
# 2            0           145            -1    -2.0    -2.0  0.554538
# 3            0          1059            -1    -2.0    -2.0  0.638699
# 4            0           711            -1  1198.0  2360.0  0.641787
# ...        ...           ...           ...     ...     ...       ...
# 23995      999           965            -1    57.0  1250.0  0.817659
# 23996      999          1075            -1   644.0  1010.0  0.845879
# 23997      999          1090            -1    -2.0    -2.0  0.544596
# 23998      999          1184            -1   301.0  1150.0  0.859984
# 23999      999           869            -1    -1.0    -1.0 -1.000000
#
#        test_pos test_item  correct_ans  order  rep  test  pair_idx  correct  \
# 0             1   CABBAGE          327      1    1     1        11     True
# 1             2    SCOTCH          819      2    1     1         8    False
# 2             3      BODY         1198      1    1     1         7    False
# 3             4    PICKLE         1391      2    1     1         5    False
# 4             5       HOE         1519      1    1     1         9    False
# ...         ...       ...          ...    ...  ...   ...       ...      ...
# 23995        20       NUT           57      2    1     2     11997     True
# 23996        21    PISTOL          644      2    1     2     11993     True
# 23997        22      PLUM         1609      2    1     2     11991    False
# 23998        23    REPORT          301      2    1     2     11996     True
# 23999        24    MARINE          222      2    1     2     12000    False
#
#       cond       cong  corr_fin  omean_fin  omax_fin
# 0      F-F  Identical -0.338427  -0.893156 -0.417645
# 1      B-B  Identical -0.484410  -1.256948 -0.488696
# 2      F-F  Identical -0.446878  -1.460890 -0.498679
# 3      B-B  Identical -0.464744  -1.659222 -0.479372
# 4      F-B   Reversed -0.455372  -1.882418 -0.477689
# ...    ...        ...       ...        ...       ...
# 23995  F-B   Reversed -0.010037  -3.078723 -0.241682
# 23996  B-B  Identical  0.036203  -3.494364 -0.249831
# 23997  B-B  Identical -0.460750  -3.922968 -0.315136
# 23998  B-B  Identical  0.034002  -4.149329 -0.552039
# 23999  F-B   Reversed -4.521227  -4.342017 -0.601313
#
# [24000 rows x 19 columns]

# %%
df_fin = df_simu.groupby(['cong','test'])[['corr_fin','omean_fin','omax_fin']].mean().reset_index()
df_fin['dif'] = df_fin['corr_fin'] - df_fin['omax_fin']
df_fin
# Out:
#         cong  test  corr_fin  omean_fin  omax_fin       dif
# 0  Identical     1 -0.648979  -2.509888 -0.519877 -0.129102
# 1  Identical     2 -0.600525  -2.416174 -0.278329 -0.322195
# 2   Reversed     1 -0.644314  -2.498674 -0.521211 -0.123103
# 3   Reversed     2 -0.619701  -2.385869 -0.284518 -0.335184

# %% [markdown]
# ### PLOT

# %%
df_simu.head(24)
# Out:
#     session  test_itemno1  test_itemno2  s_resp    s_rt      csim  test_pos  \
# 0         0           210            -1   327.0  1830.0  0.797872         1
# 1         0          1251            -1    -2.0    -2.0  0.627754         2
# 2         0           145            -1    -2.0    -2.0  0.554538         3
# 3         0          1059            -1    -2.0    -2.0  0.638699         4
# 4         0           711            -1  1198.0  2360.0  0.641787         5
# 5         0           838            -1    -2.0    -2.0  0.527408         6
# 6         0           153            -1    -2.0    -2.0  0.596206         7
# 7         0          1587            -1    -2.0    -2.0  0.575857         8
# 8         0           856            -1    -2.0    -2.0  0.545230         9
# 9         0           702            -1    -2.0    -2.0  0.572660        10
# 10        0           299            -1  1282.0  1980.0  0.650683        11
# 11        0          1372            -1    -2.0    -2.0  0.500791        12
# 12        0           140            -1   299.0  1270.0  0.677518        13
# 13        0           145            -1  1282.0  1180.0  0.668000        14
# 14        0          1169            -1    -2.0    -2.0  0.592101        15
# 15        0           299            -1  1198.0  1370.0  0.654077        16
# 16        0          1059            -1    -2.0    -2.0  0.607515        17
# 17        0          1519            -1   711.0  1040.0  0.801356        18
# 18        0           210            -1   327.0  1040.0  0.802707        19
# 19        0          1132            -1    -2.0    -2.0  0.579848        20
# 20        0          1240            -1    -2.0    -2.0  0.618026        21
# 21        0          1251            -1    -2.0    -2.0  0.637831        22
# 22        0           856            -1   819.0  3130.0  0.646000        23
# 23        0           736            -1   153.0  2370.0  0.688346        24
#
#     test_item  correct_ans  order  rep  test  pair_idx  correct cond  \
# 0     CABBAGE          327      1    1     1        11     True  F-F
# 1      SCOTCH          819      2    1     1         8    False  B-B
# 2        BODY         1198      1    1     1         7    False  F-F
# 3      PICKLE         1391      2    1     1         5    False  B-B
# 4         HOE         1519      1    1     1         9    False  F-B
# 5        LOCK          140      2    1     1         1    False  B-F
# 6      BOTTLE          736      1    1     1         6    False  F-B
# 7    WARDROBE         1240      1    1     1         2    False  F-B
# 8        MAID          607      2    1     1        10    False  B-B
# 9      HELMET         1132      2    1     1         3    False  B-F
# 10      CHILD         1282      1    1     1         4     True  F-F
# 11    STAPLER         1169      2    1     1        12    False  B-F
# 12  BLUEBERRY          838      1    1     2         1    False  B-F
# 13       BODY         1198      1    1     2         7    False  F-F
# 14        RAT         1372      1    1     2        12    False  B-F
# 15      CHILD         1282      1    1     2         4    False  F-F
# 16     PICKLE         1391      2    1     2         5    False  B-B
# 17     TUNNEL          711      2    1     2         9     True  F-B
# 18    CABBAGE          327      1    1     2        11     True  F-F
# 19     PROTON          702      1    1     2         3    False  B-F
# 20  SAXOPHONE         1587      2    1     2         2    False  F-B
# 21     SCOTCH          819      2    1     2         8    False  B-B
# 22       MAID          607      2    1     2        10    False  B-B
# 23     INDIAN          153      2    1     2         6     True  F-B
#
#          cong  corr_fin  omean_fin  omax_fin
# 0   Identical -0.338427  -0.893156 -0.417645
# 1   Identical -0.484410  -1.256948 -0.488696
# 2   Identical -0.446878  -1.460890 -0.498679
# 3   Identical -0.464744  -1.659222 -0.479372
# 4    Reversed -0.455372  -1.882418 -0.477689
# 5    Reversed -0.537589  -2.277589 -0.529091
# 6    Reversed -0.474879  -2.495031 -0.505461
# 7    Reversed -0.481294  -2.719813 -0.495151
# 8   Identical -0.469664  -2.927994 -0.531170
# 9    Reversed -0.496838  -3.151359 -0.511503
# 10  Identical -0.451344  -3.389520 -0.490048
# 11   Reversed -0.516828  -3.772192 -0.563161
# 12   Reversed -0.512808  -0.740120 -0.164244
# 13  Identical -0.158522  -1.139842 -0.182884
# 14   Reversed -0.427356  -1.542530 -0.219941
# 15  Identical -4.632330  -1.342149 -0.246269
# 16  Identical -0.408637  -1.935232 -0.282918
# 17   Reversed -0.054063  -2.177075 -0.347101
# 18  Identical  0.010409  -2.578466 -0.534376
# 19   Reversed -0.498873  -2.968961 -0.563823
# 20   Reversed -0.469666  -3.218269 -0.459366
# 21  Identical -0.487716  -3.423481 -0.499186
# 22  Identical -0.446560  -3.642186 -0.481555
# 23   Reversed -0.435023  -4.050374 -0.509149

# %%
dfgp_test_order = df_simu.groupby(['rep','test','order']).correct.mean().to_frame(name='corr_rate').reset_index()
dfgp_test_order
# Out:
#    rep  test  order  corr_rate
# 0    1     1      1   0.371667
# 1    1     1      2   0.370500
# 2    1     2      1   0.367833
# 3    1     2      2   0.364833

# %%
def contingency_tab(x):
    tmp_x = pd.pivot_table(x,index='pair_idx',columns='test', values= 'correct')
    test1 = pd.Categorical(tmp_x[1], categories=[1, 0])
    test2 = pd.Categorical(tmp_x[2], categories=[1, 0])
    return pd.crosstab(index=test2,columns=test1)

# %%
dfgp_rep_cong = df_simu.groupby(['cong']).apply(contingency_tab)
dfgp_rep_cong
# Out:
# col_0               1     0
# cong      row_0
# Identical 1      1766   318
#           0       470  3446
# Reversed  1      1783   529
#           0       434  3254

# %%
dfgp_rep_cong / 6000
# Out:
# col_0                   1         0
# cong      row_0
# Identical 1      0.294333  0.053000
#           0      0.078333  0.574333
# Reversed  1      0.297167  0.088167
#           0      0.072333  0.542333

# %%
df_simu.groupby(['cong','test']).correct.mean()
# Out:
# cong       test
# Identical  1       0.372667
#            2       0.347333
# Reversed   1       0.369500
#            2       0.385333
# Name: correct, dtype: float64

# %%
def Yule_Q(A, B, C, D):
    return (A * D - B * C) / (A * D + B * C)

# %%
tab_identical = dfgp_rep_cong.loc['Identical']
Yule_Q(tab_identical[1][1]+0.5,tab_identical[0][1]+0.5,tab_identical[1][0]+0.5,tab_identical[0][0]+0.5)
# Out:
# 0.9519551356731978

# %%
tab_reversed = dfgp_rep_cong.loc['Reversed']
Yule_Q(tab_reversed[1][1]+0.5,tab_reversed[0][1]+0.5,tab_reversed[1][0]+0.5,tab_reversed[0][0]+0.5)
# Out:
# 0.9237487941150078

# %%
Yule_Q(0.319, 0.012, 0.006, 0.663)
# Out:
# 0.9993193709853524

# %%
Yule_Q(0.293, 0.122, 0.049, 0.537)
# Out:
# 0.9267935757627709
