# %%
# randomly pick the existing design, self-generated semantic matrix
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# ### Load Real Design

# %%
df = pd.read_csv('simu1_data/cr_preproc_data_mturk.csv')
df
# Out:
#               rt  time_elapsed  subject_ID      item  lag       category  \
# 0       1640.345       71781.0         120       ARM    0  Uncategorized
# 1        845.750       71783.0         422     CELLO    0  Uncategorized
# 2            NaN       72233.0          52   HALLWAY    0       Building
# 3            NaN       72813.0          20  MOUNTAIN    0  Uncategorized
# 4            NaN       73029.0         108     ROBIN    0  Uncategorized
# ...          ...           ...         ...       ...  ...            ...
# 381055       NaN    12140412.0         228    CARROT  163     Vegetables
# 381056       NaN    12144498.0         228     GOOSE  112  Uncategorized
# 381057       NaN    12148572.0         228      PEAS   68     Vegetables
# 381058       NaN    12152653.0         228       SAW  159          Tools
# 381059       NaN    12156752.0         228   GIRAFFE  129            Zoo
#
#         confidence  correct  correct_num category_label  ... position    old  \
# 0              1.0     True            1      BodyParts  ...        0  False
# 1              5.0    False            0    Instruments  ...        0  False
# 2              NaN    False            0       Building  ...        0  False
# 3              NaN    False            0     Landscapes  ...        0  False
# 4              NaN    False            0          Birds  ...        0  False
# ...            ...      ...          ...            ...  ...      ...    ...
# 381055         NaN    False            0     Vegetables  ...      575   True
# 381056         NaN    False            0          Birds  ...      576   True
# 381057         NaN    False            0     Vegetables  ...      577   True
# 381058         NaN    False            0          Tools  ...      578   True
# 381059         NaN    False            0            Zoo  ...      579   True
#
#           yes     block_type       prev_cat prev_cat_match prev_cat_label  \
# 0       False  Uncategorized            NaN            NaN            NaN
# 1        True  Uncategorized            NaN            NaN            NaN
# 2         NaN    Categorized            NaN          False            NaN
# 3         NaN  Uncategorized            NaN            NaN            NaN
# 4         NaN  Uncategorized            NaN            NaN            NaN
# ...       ...            ...            ...            ...            ...
# 381055    NaN    Categorized     Landscapes          False     Landscapes
# 381056    NaN  Uncategorized     Vegetables            NaN     Vegetables
# 381057    NaN    Categorized  Uncategorized          False          Birds
# 381058    NaN    Categorized     Vegetables          False     Vegetables
# 381059    NaN    Categorized          Tools          False          Tools
#
#        prev_cat_label_match  curr_cat_length  curr_cat_label_length
# 0                     False              NaN                      0
# 1                     False              NaN                      0
# 2                     False              0.0                      0
# 3                     False              NaN                      0
# 4                     False              NaN                      0
# ...                     ...              ...                    ...
# 381055                False             20.0                     20
# 381056                False              NaN                     21
# 381057                False             21.0                     21
# 381058                False             22.0                     22
# 381059                False             22.0                     22
#
# [381060 rows x 21 columns]

# %%
# drop redundant columns
df = df.drop(['rt', 'time_elapsed', 'correct', 'correct_num', 'block_type', 'item_name', 'prev_cat', 'prev_cat_match', 'prev_cat_label', 'prev_cat_label_match','curr_cat_length', 'curr_cat_label_length', 'yes', 'confidence', 'category'], axis=1)
df
# Out:
#         subject_ID      item  lag category_label  position    old
# 0              120       ARM    0      BodyParts         0  False
# 1              422     CELLO    0    Instruments         0  False
# 2               52   HALLWAY    0       Building         0  False
# 3               20  MOUNTAIN    0     Landscapes         0  False
# 4              108     ROBIN    0          Birds         0  False
# ...            ...       ...  ...            ...       ...    ...
# 381055         228    CARROT  163     Vegetables       575   True
# 381056         228     GOOSE  112          Birds       576   True
# 381057         228      PEAS   68     Vegetables       577   True
# 381058         228       SAW  159          Tools       578   True
# 381059         228   GIRAFFE  129            Zoo       579   True
#
# [381060 rows x 6 columns]

# %%
# drop subject 200!!!
df = df.loc[df.subject_ID != 200]

# %%
# how many subjects
subjlist = df.subject_ID.to_numpy()
subjlist = np.unique(subjlist)
len(subjlist)
# Out:
# 656

# %%
# add itemno
items = np.unique(df.item)
item2no = {}
for i in range(len(items)):
    item2no[items[i]] = i+1
df['itemno'] = df.apply(lambda x: item2no[x.loc['item']], 1)
df
# Out:
# /tmp/ipykernel_19134/2222716781.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['itemno'] = df.apply(lambda x: item2no[x.loc['item']], 1)
#         subject_ID      item  lag category_label  position    old  itemno
# 0              120       ARM    0      BodyParts         0  False       3
# 1              422     CELLO    0    Instruments         0  False      48
# 2               52   HALLWAY    0       Building         0  False     124
# 3               20  MOUNTAIN    0     Landscapes         0  False     173
# 4              108     ROBIN    0          Birds         0  False     220
# ...            ...       ...  ...            ...       ...    ...     ...
# 381055         228    CARROT  163     Vegetables       575   True      43
# 381056         228     GOOSE  112          Birds       576   True     119
# 381057         228      PEAS   68     Vegetables       577   True     194
# 381058         228       SAW  159          Tools       578   True     228
# 381059         228   GIRAFFE  129            Zoo       579   True     115
#
# [380480 rows x 7 columns]

# %%
# organize
df = df.sort_values(by = ['subject_ID', 'position'])
df = df.reset_index(drop = True)
df = df[['subject_ID','position', 'item','itemno','category_label', 'lag', 'old']]
df
# Out:
#         subject_ID  position       item  itemno category_label  lag    old
# 0                0         0    CHICKEN      53    FarmAnimals    0  False
# 1                0         1  BLUEBERRY      26          Fruit    0  False
# 2                0         2        BUS      33       Vehicles    0  False
# 3                0         3      LEMON     151          Fruit    0  False
# 4                0         4     OYSTER     187   OceanAnimals    0  False
# ...            ...       ...        ...     ...            ...  ...    ...
# 380475         656       575       COLA      60      Beverages   37   True
# 380476         656       576   BASEBALL      10           Toys  115   True
# 380477         656       577        TEA     265      Beverages   24   True
# 380478         656       578      RADIO     213    Electronics   41   True
# 380479         656       579      FINCH      99          Birds   81   True
#
# [380480 rows x 7 columns]

# %% [markdown]
# ### Design

# %%
rng = np.random.default_rng(seed=42)
simu_sess_num = 1000

subjectlist = np.unique(df.subject_ID)
sess = rng.choice(subjectlist, simu_sess_num)
sess
# Out:
# array([ 58, 508, 430, 288, 285, 564,  56, 458, 132,  61, 346, 641, 483,
#        500, 471, 516, 337,  84, 551, 296, 329, 244, 119, 608, 513, 423,
#        264, 540, 358, 291, 296, 149,  60, 364, 583,  41, 564, 543, 181,
#        415, 108, 498, 460, 233,  44, 637, 293, 586, 445, 511, 499, 127,
#        239, 307, 327,  28, 359, 101, 488, 449, 606, 489, 241, 635, 270,
#        214, 595, 244,  50, 309, 522, 124, 304,  85, 451, 313, 217, 148,
#        371, 440, 617, 287, 105, 547, 414, 460,  63, 205, 504, 546, 286,
#        528, 553, 255, 590, 189, 157, 448, 418,  91, 547, 131, 529,   4,
#        523, 517, 512, 437, 310, 463, 181, 513, 365, 302, 332, 374,  24,
#         91, 161,  75, 289, 439, 430, 310, 561, 371,  51, 502, 377, 417,
#        371, 364,  59, 367, 522, 199, 396,  20, 228, 287, 645, 140, 181,
#        268, 652, 560,  22, 153, 540,  38, 562, 184, 602, 192, 285, 435,
#         82, 366, 332, 515, 654, 436, 269, 267, 275, 534, 211, 109, 220,
#         14,  69,  59, 507, 474, 458, 303, 471, 105, 591, 329, 616,  99,
#        327, 457, 326, 293, 109, 250, 156, 197, 449, 414, 399, 238, 630,
#         57, 225,  77, 223, 632, 241, 597, 325, 460, 301, 174, 502, 636,
#        172, 511, 171, 471, 518, 295, 484, 178,  51,  63, 294, 593,  83,
#        299, 462, 132, 474, 201, 531, 380, 359, 115, 304, 562,  12, 498,
#        324, 472, 436, 284, 203, 412,  91, 384,  62, 427, 413,  55, 497,
#        273, 517,  27, 117, 325, 123, 217, 434,  94, 445,  67, 114, 386,
#        521, 111, 196, 607, 650, 382, 294, 228, 402, 388, 193,  14,  99,
#        629, 275, 317, 307, 514,  42,  54, 180, 320, 441, 322, 290, 616,
#        105, 376, 356, 311, 530, 175, 626, 218, 358, 342, 558, 288, 186,
#         14, 239, 543,   6, 588, 357,  92, 198, 364, 208,  71, 437, 441,
#         77, 184, 159, 433, 480, 477, 616, 505, 211,  70, 404, 601, 640,
#        151, 155,  24,  92, 364, 359, 244, 204, 545, 302, 531, 632, 209,
#        132, 626, 417, 190, 408, 338, 595, 167, 651, 615, 118, 107, 350,
#         29, 196, 286, 636, 651,  99, 585,  59, 492, 555, 585, 146, 587,
#         76, 341, 309, 208,  14, 507, 221, 435, 270, 246, 582,  61, 484,
#        490, 250, 172,   3, 615, 622, 158,  20,  80,  44, 546, 586, 100,
#        490, 117, 241, 394, 473, 574,  29, 128, 184, 204, 655, 510, 211,
#        638, 328, 329, 285,  94, 613,   9, 114, 150, 183,  86,  11, 445,
#        636,  79, 194, 333, 609, 456, 503, 382, 274, 131, 567, 528,  16,
#        470,  55, 485, 542,  85, 285,  81, 373, 609,  53, 261, 639, 197,
#         86, 321, 334, 435, 206, 627, 342, 187, 630, 607, 328,  16, 392,
#        365,  97, 416, 552,  69, 475,  92, 492, 275,   4, 634, 108, 392,
#        119, 613, 485, 528, 284, 307, 417, 515, 556,  11, 436,  71, 188,
#        545, 164, 523, 304, 152, 220, 349, 502, 398, 613, 570, 495, 396,
#        190, 271,  77, 246, 608, 280,  74, 428, 632, 570, 179, 298, 349,
#        162, 176, 155, 653, 490, 552, 536, 630,  69, 579,  43, 312, 390,
#        235,  95, 126, 541, 210, 204, 606,  94, 601, 605, 393, 108, 102,
#        186, 379, 100, 299,  75, 355,  13, 466,  36, 127, 114, 546,  35,
#        282, 388, 339, 447, 527, 259, 544, 209, 646, 331, 483, 575, 520,
#        559, 352,  28, 324, 119, 584, 155, 149, 163, 422, 375, 623, 274,
#        185,  32,   4, 246, 608, 344, 587,  66,  61, 547,  70,  34, 266,
#        607, 453,  65, 550, 554, 526, 593, 157, 643, 211, 527, 381, 512,
#        412, 422, 405, 512, 485,  88, 542, 352, 212, 338, 635, 563, 547,
#        304, 515, 253, 451, 420, 163, 174,  40,  91, 285, 314, 108, 274,
#        397, 152, 222, 242, 332, 241, 484, 215, 285, 249, 119, 450, 154,
#        194, 521, 623, 441, 602, 561, 316, 506, 216, 303, 352, 631, 557,
#        321, 429, 132, 528, 363, 350, 503, 416,  47, 189, 115, 483,  23,
#        132, 392, 456, 331, 565, 603,  86, 625, 404, 418,  62, 408, 477,
#        381,  55, 344, 614, 475,  90, 630, 630, 111, 526, 267, 390, 293,
#        514, 654, 522, 611, 621,  59, 166, 474, 388,  32,  62, 342, 405,
#        110, 112,  84, 371,   5, 376, 313, 306, 446, 343, 478, 502, 604,
#        525, 340, 323, 154, 394,  91, 611, 555,  78, 516,  76, 474,  57,
#        321, 432, 479, 275, 605, 508, 136, 441, 480, 219, 485, 590, 537,
#        501, 417, 177, 522, 239, 350, 207, 206, 103, 631,  96,  56, 615,
#        365, 288, 484, 252,  83, 479, 115, 363, 623, 615, 237, 512, 402,
#        315,  91, 247, 428, 648,   3, 471, 556, 624, 279,  77, 177, 558,
#        576, 418,  80,  79, 314, 386,  21, 451, 358,   8,  62, 299, 475,
#        542, 283, 193, 636, 301, 207, 291,   7, 198, 339, 603, 485, 513,
#        358,  72, 257, 655,  28, 577, 450, 186, 511, 550,  28,  69, 437,
#        656,  15, 437,  89, 427, 409,  59, 447, 589, 567,  19, 161, 157,
#        298,  93, 561, 510, 531, 130,   9, 598, 189, 431, 597,  23,   3,
#          3, 102,  33, 538, 398, 643, 526, 632, 156, 188, 558, 160,  37,
#        439, 526, 636, 609,  78, 507, 556, 458, 538, 550, 293,  26, 300,
#        132,  74,  81, 458, 331, 355, 489, 360, 414,  56, 559, 295, 101,
#        534, 482,  34, 126,  10, 177,  65, 466, 343, 644, 492, 402, 335,
#         35,  46, 405,   2,  27, 143, 580, 302, 466, 270, 113, 244,  60,
#        506, 120, 247, 643, 389, 301, 357, 515, 166, 418, 573, 376, 293,
#         95, 162, 621, 356, 197, 275, 380, 353, 460, 168, 426, 291, 618,
#        103,  97, 303, 334, 454, 266, 600, 312,  84,  78, 639,  87, 622,
#        182,  61, 199, 404, 281, 516, 401, 263, 417, 638, 271, 100, 269,
#        552, 142, 623, 386, 395, 208, 604,  23, 195, 275, 314, 312,  97,
#        147,  62, 376, 231, 372, 387, 461, 359, 426, 386, 428, 405, 208,
#        161, 517, 225, 361, 129, 284, 348, 411, 346, 237, 631, 337])

# %%
df_test = pd.DataFrame()
for i in range(len(sess)):
    tmp = df.loc[df.subject_ID == sess[i],:].copy()
    tmp["session"] = i
    df_test = pd.concat([df_test, tmp])
df_test = df_test.reset_index(drop=True)
df_test['study_itemno1'] = df_test['itemno']
df_test['study_itemno2'] = -1
df_test['test_itemno1'] = df_test['itemno']
df_test['test_itemno2'] = -1
df_test
# Out:
#         subject_ID  position       item  itemno category_label  lag    old  \
# 0               58         0  UNDERWEAR     282       Clothing    0  False
# 1               58         1      JEANS     139       Clothing    0  False
# 2               58         2     JACKET     138       Clothing    0  False
# 3               58         3     TABLET     263    Electronics    0  False
# 4               58         4   COMPUTER      62    Electronics    0  False
# ...            ...       ...        ...     ...            ...  ...    ...
# 579995         337       575       LAKE     148     Landscapes    0  False
# 579996         337       576        PIE     201       Desserts   78   True
# 579997         337       577    LOBSTER     160   OceanAnimals   90   True
# 579998         337       578      MAPLE     161          Trees  118   True
# 579999         337       579     WASHER     290     Appliances  112   True
#
#         session  study_itemno1  study_itemno2  test_itemno1  test_itemno2
# 0             0            282             -1           282            -1
# 1             0            139             -1           139            -1
# 2             0            138             -1           138            -1
# 3             0            263             -1           263            -1
# 4             0             62             -1            62            -1
# ...         ...            ...            ...           ...           ...
# 579995      999            148             -1           148            -1
# 579996      999            201             -1           201            -1
# 579997      999            160             -1           160            -1
# 579998      999            161             -1           161            -1
# 579999      999            290             -1           290            -1
#
# [580000 rows x 12 columns]

# %%
# save
with open('simu1_data/simu1_design.pkl', 'wb') as outp:
    pickle.dump(df_test, outp, pickle.HIGHEST_PROTOCOL)
