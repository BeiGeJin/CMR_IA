# %%
import numpy as np
import pickle
import math
import matplotlib.pyplot as plt
import pandas as pd
import time
import pprint
import seaborn as sns
import CMR_IA as cmr
import scipy as sp
sns.set_context('paper')
np.set_printoptions(suppress=True)
# pd.set_option('display.max_columns', None)

# %%
def simu_success(tag, params):
    # which task
    if tag == "Asso-CR":
        path = "../Data/simuS1_group1_design.pkl"
        nitems = 96
        test1_num = 40
    elif tag == "Pair-CR":
        path = "../Data/simuS1_group2_design.pkl"
        nitems = 176
        test1_num = 80
    elif tag == "Item-CR":
        path = "../Data/simuS1_group3_design.pkl"
        nitems = 136
        test1_num = 80

    # load stimuli
    with open(path, 'rb') as inp:
        df_study = pickle.load(inp)
        df_test = pickle.load(inp)
    # df_study = df_study.loc[df_study.session < 200]
    # df_test = df_test.loc[df_test.session < 200]

    # load semantic matrix
    s_mat = np.load('../Data/wordpools/ltp_FR_similarity_matrix.npy')

    # update n_item in params to fit the study
    params.update(nitems_in_accumulator = nitems)
    # print(params)

    # run CMR
    df_simu, f_in_acc, f_in_dif = cmr.run_success_multi_sess(params, df_study, df_test ,s_mat)
    df_simu['test'] = df_test['test']
    df_simu = df_simu.merge(df_test,on=['session','test','test_itemno1','test_itemno2'])

    # get f_in
    sessions = np.unique(df_simu.session)
    tmp_corr_fin = []
    tmp_omax_fin = []

    for sess in sessions:
        df_tmp = df_study.loc[df_study.session == sess]
        tmp1 = df_tmp.study_itemno1.to_numpy()
        tmp2 = df_tmp.study_itemno2.to_numpy()
        df_tmp2 = df_test.loc[df_test.session == sess]
        tmp3 = df_tmp2.test_itemno1[df_tmp2.test_itemno1 >= 0].to_numpy()
        tmp4 = df_tmp2.test_itemno2[df_tmp2.test_itemno2 >= 0].to_numpy()
        tmp = np.concatenate((tmp1, tmp2, tmp3, tmp4))
        tmp = np.unique(tmp)  # sort

        tmp_corr = df_simu.loc[df_simu.session == sess,"correct_ans"][test1_num:]
        corrid = np.searchsorted(tmp, tmp_corr)

        corr_fin = [f_in_dif[sess][i][id] for i, id in enumerate(corrid)]
        omax_fin = [np.max(np.delete(f_in_dif[sess][i], id)) for i, id in enumerate(corrid)]

        tmp_corr_fin = tmp_corr_fin + [-1] * test1_num + corr_fin
        tmp_omax_fin = tmp_omax_fin + [-1] * test1_num + omax_fin

    df_simu['corr_fin'] = tmp_corr_fin
    df_simu['omax_fin'] = tmp_omax_fin

    # optimal threshold for test1
    csim_two = df_simu.query("test==1").groupby("correct_ans").csim.mean()
    opt_thresh = np.mean(csim_two)
    df_simu['s_resp'] = df_simu.apply(lambda x: (1 if x['csim'] > opt_thresh else 0) if x['test'] == 1 else x['s_resp'], axis=1)

    return df_simu

# %%
def anal_perform(df_simu):

    # get correctness
    df_simu['correct'] = df_simu.s_resp == df_simu.correct_ans

    # recognition performance
    df_recog = df_simu.query("test==1")
    hr_far = df_recog.groupby("correct_ans")["s_resp"].mean().to_frame(name="Yes rate")
    hr = hr_far['Yes rate'][0]
    far = hr_far['Yes rate'][1]
    z_hr_far = sp.stats.norm.ppf(hr_far)
    d_prime = z_hr_far[1].item() - z_hr_far[0].item()
    print("recognition: \n", hr_far)
    print("d_prime: ", d_prime)

    # cued recall performance
    df_cr = df_simu.query("test==2")
    p_rc = df_cr.correct.mean()
    print("cued recall: \n", p_rc)

    # analyze pair
    def get_pair(df_tmp):
        df_tmp_pair = pd.pivot_table(df_tmp,index="pair_idx",columns="test",values="correct")
        df_tmp_pair.columns = ["test1","test2"]
        df_tmp_pair.reset_index(inplace=True)
        return df_tmp_pair

    df_simu_p = df_simu.query("pair_idx >= 0")
    df_pair = df_simu_p.groupby("session").apply(get_pair).reset_index()
    df_tab = pd.crosstab(index=df_pair.test2,columns=df_pair.test1,normalize=False)
    print("contingency table: \n", df_tab)
    print("contingency table norm: \n", pd.crosstab(index=df_pair.test2,columns=df_pair.test1,normalize='all'))

    # compute" Q
    def Yule_Q(A, B, C, D):
        return (A * D - B * C) / (A * D + B * C)
    q = Yule_Q(df_tab[1][1]+0.5,df_tab[0][1]+0.5,df_tab[1][0]+0.5,df_tab[0][0]+0.5)  # add 0.5
    print("Q: ", q)

    return p_rc, hr, far, d_prime, q

# %% [markdown]
# ### Study Params

# %%
# study params should be the same across three groups
params = cmr.make_default_params()
params.update(
    beta_enc = 0.3,
    gamma_fc = 0.2,
    gamma_cf = 0.2,
    s_fc = 0.2,
    s_cf = 0.2,
    phi_s = 1,
    phi_d = 0.6,
    d_ass = 1,
    learn_while_retrieving = False,
    var_enc = 1,
    bad_enc_ratio = 1,
)

# %%
params.update(
    beta_cue = 0.4,
    beta_rec = 0.1,  # beta for retrieved item
    beta_distract = 0.1,
    # beta_rec_post = 0.1,
    c_thresh = 0.01,
    c_thresh_ass = 0.5,
    kappa = 0.01,
    lamb = 0.002,
    eta = 0.002,
    omega = 3,
    alpha = 1
)
params
# Out:
# {'beta_enc': 0.3,
#  'beta_rec': 0.1,
#  'beta_cue': 0.4,
#  'beta_rec_post': 0.5,
#  'beta_distract': 0.1,
#  'phi_s': 1,
#  'phi_d': 0.6,
#  's_cf': 0.2,
#  's_fc': 0.2,
#  'kappa': 0.01,
#  'eta': 0.002,
#  'omega': 3,
#  'alpha': 1,
#  'c_thresh': 0.01,
#  'c_thresh_ass': 0.5,
#  'd_ass': 1,
#  'lamb': 0.002,
#  'rec_time_limit': 60000.0,
#  'dt': 10,
#  'nitems_in_accumulator': 50,
#  'max_recalls': 50,
#  'learn_while_retrieving': False,
#  'a': 2800,
#  'b': 20,
#  'm': 0,
#  'n': 1,
#  'c1': 0,
#  'No_recall': None,
#  'var_enc': 1,
#  'bad_enc_ratio': 1,
#  'gamma_fc': 0.2,
#  'gamma_cf': 0.2}

# %% [markdown]
# ### Association - CR (Group1)

# %%
rng = np.random.default_rng()

# %%
tag = "Asso-CR"
df_simu_g1 = simu_success(tag, params)
# Out:
# CMR2 Time: 68.6192991733551

# %%
n_subj = 30
n_per_subj = 3
g1_sesses = rng.choice(np.arange(1000),n_subj*n_per_subj,replace=False)

# %%
g1_stats = []
for i in range(n_subj):
    this_sesses = g1_sesses[n_per_subj*i:n_per_subj*(i+1)]
    this_df = df_simu_g1.loc[np.isin(df_simu_g1.session, this_sesses)].copy()    
    p_rc, hr, far, d_prime, q = anal_perform(this_df)
    g1_stats.append([p_rc, hr, far, d_prime, q])
# Out:
# recognition:
#               Yes rate
# correct_ans
# 0            0.100000
# 1            0.916667
# d_prime:  2.6645456926452384
# cued recall:
#  0.4166666666666667
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      5   30
# 1.0      0   25
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.083333  0.500000
# 1.0    0.000000  0.416667
# Q:  0.8038585209003215
# recognition:
#               Yes rate
# correct_ans
# 0            0.183333
# 1            0.850000
# d_prime:  1.9391681811376547
# cued recall:
#  0.6166666666666667
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      8   15
# 1.0      1   36
# contingency table norm:
#  test1       0.0   1.0
# test2
# 0.0    0.133333  0.25
# 1.0    0.016667  0.60
# Q:  0.8605697151424287
# recognition:
#               Yes rate
# correct_ans
# 0            0.183333
# 1            0.866667
# d_prime:  2.01350640828065
# cued recall:
#  0.4666666666666667
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      8   24
# 1.0      0   28
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.133333  0.400000
# 1.0    0.000000  0.466667
# Q:  0.9037328094302554
# recognition:
#               Yes rate
# correct_ans
# 0                0.20
# 1                0.85
# d_prime:  1.8780546230667041
# cued recall:
#  0.4
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      8   28
# 1.0      1   23
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.133333  0.466667
# 1.0    0.016667  0.383333
# Q:  0.6474226804123712
# recognition:
#               Yes rate
# correct_ans
# 0            0.233333
# 1            0.866667
# d_prime:  1.8386849075184295
# cued recall:
#  0.3333333333333333
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      7   33
# 1.0      1   19
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.116667  0.550000
# 1.0    0.016667  0.316667
# Q:  0.48854961832061067
# recognition:
#               Yes rate
# correct_ans
# 0            0.183333
# 1            0.900000
# d_prime:  2.184286357188465
# cued recall:
#  0.4166666666666667
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      5   30
# 1.0      1   24
# contingency table norm:
#  test1       0.0  1.0
# test2
# 0.0    0.083333  0.5
# 1.0    0.016667  0.4
# Q:  0.4930747922437673
# recognition:
#               Yes rate
# correct_ans
# 0                0.15
# 1                0.85
# d_prime:  2.0728667789875797
# cued recall:
#  0.4
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      7   29
# 1.0      2   22
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.116667  0.483333
# 1.0    0.033333  0.366667
# Q:  0.3917525773195876
# recognition:
#               Yes rate
# correct_ans
# 0            0.233333
# 1            0.883333
# d_prime:  1.9197294625630383
# cued recall:
#  0.4
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      7   29
# 1.0      0   24
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.116667  0.483333
# 1.0    0.000000  0.400000
# Q:  0.8513853904282116
# recognition:
#               Yes rate
# correct_ans
# 0            0.216667
# 1            0.766667
# d_prime:  1.5114136662714186
# cued recall:
#  0.4
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     14   22
# 1.0      0   24
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.233333  0.366667
# 1.0    0.000000  0.400000
# Q:  0.9386084583901774
# recognition:
#               Yes rate
# correct_ans
# 0            0.200000
# 1            0.883333
# d_prime:  2.033437405254308
# cued recall:
#  0.45
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      7   26
# 1.0      0   27
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.116667  0.433333
# 1.0    0.000000  0.450000
# Q:  0.8792710706150342
# recognition:
#               Yes rate
# correct_ans
# 0            0.200000
# 1            0.916667
# d_prime:  2.2246153606735524
# cued recall:
#  0.45
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      5   28
# 1.0      0   27
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.083333  0.466667
# 1.0    0.000000  0.450000
# Q:  0.8277945619335347
# recognition:
#               Yes rate
# correct_ans
# 0            0.183333
# 1            0.966667
# d_prime:  2.7366494274597795
# cued recall:
#  0.45
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      2   31
# 1.0      0   27
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.033333  0.516667
# 1.0    0.000000  0.450000
# Q:  0.6272189349112426
# recognition:
#               Yes rate
# correct_ans
# 0            0.133333
# 1            0.900000
# d_prime:  2.3923231821813857
# cued recall:
#  0.38333333333333336
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      6   31
# 1.0      0   23
# contingency table norm:
#  test1  0.0       1.0
# test2
# 0.0    0.1  0.516667
# 1.0    0.0  0.383333
# Q:  0.8130563798219584
# recognition:
#               Yes rate
# correct_ans
# 0            0.183333
# 1            0.816667
# d_prime:  1.8054695832877297
# cued recall:
#  0.4666666666666667
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     10   22
# 1.0      1   27
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.166667  0.366667
# 1.0    0.016667  0.450000
# Q:  0.7906976744186046
# recognition:
#               Yes rate
# correct_ans
# 0            0.183333
# 1            0.800000
# d_prime:  1.7443560252167791
# cued recall:
#  0.4166666666666667
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     11   24
# 1.0      1   24
# contingency table norm:
#  test1       0.0  1.0
# test2
# 0.0    0.183333  0.4
# 1.0    0.016667  0.4
# Q:  0.7692307692307693
# recognition:
#               Yes rate
# correct_ans
# 0            0.133333
# 1            0.833333
# d_prime:  2.0781931827384863
# cued recall:
#  0.38333333333333336
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      8   29
# 1.0      2   21
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.133333  0.483333
# 1.0    0.033333  0.350000
# Q:  0.4249512670565302
# recognition:
#               Yes rate
# correct_ans
# 0                0.10
# 1                0.95
# d_prime:  2.9264051924960723
# cued recall:
#  0.5166666666666667
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      2   27
# 1.0      1   30
# contingency table norm:
#  test1       0.0   1.0
# test2
# 0.0    0.033333  0.45
# 1.0    0.016667  0.50
# Q:  0.2978723404255319
# recognition:
#               Yes rate
# correct_ans
# 0            0.183333
# 1            0.916667
# d_prime:  2.285728918744503
# cued recall:
#  0.6
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      2   22
# 1.0      3   33
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.033333  0.366667
# 1.0    0.050000  0.550000
# Q:  0.03076923076923077
# recognition:
#               Yes rate
# correct_ans
# 0            0.183333
# 1            0.916667
# d_prime:  2.285728918744503
# cued recall:
#  0.5333333333333333
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      4   24
# 1.0      1   31
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.066667  0.400000
# 1.0    0.016667  0.516667
# Q:  0.5882352941176471
# recognition:
#               Yes rate
# correct_ans
# 0                 0.2
# 1                 0.9
# d_prime:  2.1231727991175147
# cued recall:
#  0.48333333333333334
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      5   26
# 1.0      1   28
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.083333  0.433333
# 1.0    0.016667  0.466667
# Q:  0.5954198473282443
# recognition:
#               Yes rate
# correct_ans
# 0                 0.2
# 1                 0.9
# d_prime:  2.1231727991175147
# cued recall:
#  0.5333333333333333
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      5   23
# 1.0      1   31
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.083333  0.383333
# 1.0    0.016667  0.516667
# Q:  0.6618705035971223
# recognition:
#               Yes rate
# correct_ans
# 0            0.166667
# 1            0.850000
# d_prime:  2.0038549555954908
# cued recall:
#  0.4
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      8   28
# 1.0      1   23
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.133333  0.466667
# 1.0    0.016667  0.383333
# Q:  0.6474226804123712
# recognition:
#               Yes rate
# correct_ans
# 0                0.20
# 1                0.85
# d_prime:  1.8780546230667041
# cued recall:
#  0.38333333333333336
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      9   28
# 1.0      0   23
# contingency table norm:
#  test1   0.0       1.0
# test2
# 0.0    0.15  0.466667
# 1.0    0.00  0.383333
# Q:  0.88
# recognition:
#               Yes rate
# correct_ans
# 0            0.183333
# 1            0.916667
# d_prime:  2.285728918744503
# cued recall:
#  0.43333333333333335
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      5   29
# 1.0      0   26
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.083333  0.483333
# 1.0    0.000000  0.433333
# Q:  0.8161993769470405
# recognition:
#               Yes rate
# correct_ans
# 0            0.216667
# 1            0.866667
# d_prime:  1.8942719920265594
# cued recall:
#  0.45
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      6   27
# 1.0      2   25
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.100000  0.450000
# 1.0    0.033333  0.416667
# Q:  0.4136460554371002
# recognition:
#               Yes rate
# correct_ans
# 0            0.216667
# 1            0.933333
# d_prime:  2.284586321433799
# cued recall:
#  0.38333333333333336
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      3   34
# 1.0      1   22
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.050000  0.566667
# 1.0    0.016667  0.366667
# Q:  0.20689655172413793
# recognition:
#               Yes rate
# correct_ans
# 0            0.183333
# 1            0.900000
# d_prime:  2.184286357188465
# cued recall:
#  0.5333333333333333
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      6   22
# 1.0      0   32
# contingency table norm:
#  test1  0.0       1.0
# test2
# 0.0    0.1  0.366667
# 1.0    0.0  0.533333
# Q:  0.898876404494382
# recognition:
#               Yes rate
# correct_ans
# 0            0.166667
# 1            0.916667
# d_prime:  2.350415693202339
# cued recall:
#  0.43333333333333335
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      5   29
# 1.0      0   26
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.083333  0.483333
# 1.0    0.000000  0.433333
# Q:  0.8161993769470405
# recognition:
#               Yes rate
# correct_ans
# 0            0.216667
# 1            0.850000
# d_prime:  1.8199337648835638
# cued recall:
#  0.35
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      8   31
# 1.0      1   20
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.133333  0.516667
# 1.0    0.016667  0.333333
# Q:  0.5733634311512416
# recognition:
#               Yes rate
# correct_ans
# 0            0.133333
# 1            0.916667
# d_prime:  2.4937657437374234
# cued recall:
#  0.4166666666666667
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      5   30
# 1.0      0   25
# contingency table norm:
#  test1       0.0       1.0
# test2
# 0.0    0.083333  0.500000
# 1.0    0.000000  0.416667
# Q:  0.8038585209003215

# %%
print(np.array(g1_stats))
print(np.mean(np.array(g1_stats),axis=0))
print(sp.stats.sem(np.array(g1_stats),axis=0))
# Out:
# [[0.41666667 0.1        0.91666667 2.66454569 0.80385852]
#  [0.61666667 0.18333333 0.85       1.93916818 0.86056972]
#  [0.46666667 0.18333333 0.86666667 2.01350641 0.90373281]
#  [0.4        0.2        0.85       1.87805462 0.64742268]
#  [0.33333333 0.23333333 0.86666667 1.83868491 0.48854962]
#  [0.41666667 0.18333333 0.9        2.18428636 0.49307479]
#  [0.4        0.15       0.85       2.07286678 0.39175258]
#  [0.4        0.23333333 0.88333333 1.91972946 0.85138539]
#  [0.4        0.21666667 0.76666667 1.51141367 0.93860846]
#  [0.45       0.2        0.88333333 2.03343741 0.87927107]
#  [0.45       0.2        0.91666667 2.22461536 0.82779456]
#  [0.45       0.18333333 0.96666667 2.73664943 0.62721893]
#  [0.38333333 0.13333333 0.9        2.39232318 0.81305638]
#  [0.46666667 0.18333333 0.81666667 1.80546958 0.79069767]
#  [0.41666667 0.18333333 0.8        1.74435603 0.76923077]
#  [0.38333333 0.13333333 0.83333333 2.07819318 0.42495127]
#  [0.51666667 0.1        0.95       2.92640519 0.29787234]
#  [0.6        0.18333333 0.91666667 2.28572892 0.03076923]
#  [0.53333333 0.18333333 0.91666667 2.28572892 0.58823529]
#  [0.48333333 0.2        0.9        2.1231728  0.59541985]
#  [0.53333333 0.2        0.9        2.1231728  0.6618705 ]
#  [0.4        0.16666667 0.85       2.00385496 0.64742268]
#  [0.38333333 0.2        0.85       1.87805462 0.88      ]
#  [0.43333333 0.18333333 0.91666667 2.28572892 0.81619938]
#  [0.45       0.21666667 0.86666667 1.89427199 0.41364606]
#  [0.38333333 0.21666667 0.93333333 2.28458632 0.20689655]
#  [0.53333333 0.18333333 0.9        2.18428636 0.8988764 ]
#  [0.43333333 0.16666667 0.91666667 2.35041569 0.81619938]
#  [0.35       0.21666667 0.85       1.81993376 0.57336343]
#  [0.41666667 0.13333333 0.91666667 2.49376574 0.80385852]]
# [0.44333333 0.18166667 0.88166667 2.13254691 0.65806016]
# [0.01244657 0.00625909 0.00816301 0.05647444 0.04198852]

# %% [markdown]
# ### Pair - CR (Group2)

# %%
tag = "Pair-CR"
df_simu_g2 = simu_success(tag, params)
# Out:
# CMR2 Time: 146.84375882148743

# %%
n_subj = 30
n_per_subj = 5
g2_sesses = rng.choice(np.arange(1000),n_subj*n_per_subj,replace=False)

# %%
g2_stats = []
for i in range(n_subj):
    this_sesses = g2_sesses[n_per_subj*i:n_per_subj*(i+1)]
    this_df = df_simu_g2.loc[np.isin(df_simu_g2.session, this_sesses)].copy()    
    p_rc, hr, far, d_prime, q = anal_perform(this_df)
    g2_stats.append([p_rc, hr, far, d_prime, q])
# Out:
# recognition:
#               Yes rate
# correct_ans
# 0                0.01
# 1                0.95
# d_prime:  3.971201500992313
# cued recall:
#  0.44
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     10  102
# 1.0      0   88
# contingency table norm:
#  test1   0.0   1.0
# test2
# 0.0    0.05  0.51
# 1.0    0.00  0.44
# Q:  0.8954614992350841
# recognition:
#               Yes rate
# correct_ans
# 0               0.005
# 1               0.980
# d_prime:  4.629578214180723
# cued recall:
#  0.43
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      4  110
# 1.0      0   86
# contingency table norm:
#  test1   0.0   1.0
# test2
# 0.0    0.02  0.55
# 1.0    0.00  0.43
# Q:  0.7514060742407199
# recognition:
#               Yes rate
# correct_ans
# 0                0.04
# 1                0.98
# d_prime:  3.8044349818839924
# cued recall:
#  0.41
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      4  114
# 1.0      0   82
# contingency table norm:
#  test1   0.0   1.0
# test2
# 0.0    0.02  0.57
# 1.0    0.00  0.41
# Q:  0.7327887981330222
# recognition:
#               Yes rate
# correct_ans
# 0               0.015
# 1               0.970
# d_prime:  4.050883985735812
# cued recall:
#  0.41
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      6  112
# 1.0      0   82
# contingency table norm:
#  test1   0.0   1.0
# test2
# 0.0    0.03  0.56
# 1.0    0.00  0.41
# Q:  0.810126582278481
# recognition:
#               Yes rate
# correct_ans
# 0               0.030
# 1               0.975
# d_prime:  3.840757592691305
# cued recall:
#  0.435
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      4  109
# 1.0      1   86
# contingency table norm:
#  test1    0.0    1.0
# test2
# 0.0    0.020  0.545
# 1.0    0.005  0.430
# Q:  0.4065040650406504
# recognition:
#               Yes rate
# correct_ans
# 0               0.025
# 1               0.965
# d_prime:  3.771874657492652
# cued recall:
#  0.415
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      6  111
# 1.0      1   82
# contingency table norm:
#  test1    0.0    1.0
# test2
# 0.0    0.030  0.555
# 1.0    0.005  0.410
# Q:  0.5245202558635395
# recognition:
#               Yes rate
# correct_ans
# 0               0.025
# 1               0.985
# d_prime:  4.130054362124614
# cued recall:
#  0.31
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      3  135
# 1.0      0   62
# contingency table norm:
#  test1    0.0    1.0
# test2
# 0.0    0.015  0.675
# 1.0    0.000  0.310
# Q:  0.5270506108202443
# recognition:
#               Yes rate
# correct_ans
# 0               0.025
# 1               0.980
# d_prime:  4.013712895171877
# cued recall:
#  0.385
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      4  119
# 1.0      0   77
# contingency table norm:
#  test1   0.0    1.0
# test2
# 0.0    0.02  0.595
# 1.0    0.00  0.385
# Q:  0.7074663402692778
# recognition:
#               Yes rate
# correct_ans
# 0               0.005
# 1               0.965
# d_prime:  4.387739976501498
# cued recall:
#  0.4
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      7  113
# 1.0      0   80
# contingency table norm:
#  test1    0.0    1.0
# test2
# 0.0    0.035  0.565
# 1.0    0.000  0.400
# Q:  0.8281604844814534
# recognition:
#               Yes rate
# correct_ans
# 0               0.035
# 1               0.960
# d_prime:  3.5625967442047672
# cued recall:
#  0.37
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      8  118
# 1.0      0   74
# contingency table norm:
#  test1   0.0   1.0
# test2
# 0.0    0.04  0.59
# 1.0    0.00  0.37
# Q:  0.8288808664259928
# recognition:
#               Yes rate
# correct_ans
# 0                0.00
# 1                0.98
# d_prime:  inf
# cued recall:
#  0.385
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      4  119
# 1.0      0   77
# contingency table norm:
#  test1   0.0    1.0
# test2
# 0.0    0.02  0.595
# 1.0    0.00  0.385
# Q:  0.7074663402692778
# recognition:
#               Yes rate
# correct_ans
# 0               0.040
# 1               0.965
# d_prime:  3.5625967442047672
# cued recall:
#  0.42
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      7  109
# 1.0      0   84
# contingency table norm:
#  test1    0.0    1.0
# test2
# 0.0    0.035  0.545
# 1.0    0.000  0.420
# Q:  0.840958605664488
# recognition:
#               Yes rate
# correct_ans
# 0                0.02
# 1                0.99
# d_prime:  4.380096784672664
# cued recall:
#  0.375
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      2  123
# 1.0      0   75
# contingency table norm:
#  test1   0.0    1.0
# test2
# 0.0    0.01  0.615
# 1.0    0.00  0.375
# Q:  0.5069860279441117
# recognition:
#               Yes rate
# correct_ans
# 0               0.015
# 1               0.980
# d_prime:  4.223839288216383
# cued recall:
#  0.435
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      3  110
# 1.0      1   86
# contingency table norm:
#  test1    0.0   1.0
# test2
# 0.0    0.015  0.55
# 1.0    0.005  0.43
# Q:  0.29242262540021347
# recognition:
#               Yes rate
# correct_ans
# 0               0.010
# 1               0.985
# d_prime:  4.496438251625401
# cued recall:
#  0.485
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      3  100
# 1.0      0   97
# contingency table norm:
#  test1    0.0    1.0
# test2
# 0.0    0.015  0.500
# 1.0    0.000  0.485
# Q:  0.7432950191570882
# recognition:
#               Yes rate
# correct_ans
# 0               0.025
# 1               0.975
# d_prime:  3.9199279690801085
# cued recall:
#  0.365
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      4  123
# 1.0      1   72
# contingency table norm:
#  test1    0.0    1.0
# test2
# 0.0    0.020  0.615
# 1.0    0.005  0.360
# Q:  0.2756598240469208
# recognition:
#               Yes rate
# correct_ans
# 0               0.030
# 1               0.975
# d_prime:  3.840757592691305
# cued recall:
#  0.43
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      4  110
# 1.0      1   85
# contingency table norm:
#  test1    0.0    1.0
# test2
# 0.0    0.020  0.550
# 1.0    0.005  0.425
# Q:  0.3978201634877384
# recognition:
#               Yes rate
# correct_ans
# 0                0.01
# 1                0.98
# d_prime:  4.380096784672663
# cued recall:
#  0.47
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      2  104
# 1.0      2   92
# contingency table norm:
#  test1   0.0   1.0
# test2
# 0.0    0.01  0.52
# 1.0    0.01  0.46
# Q:  -0.06091370558375635
# recognition:
#               Yes rate
# correct_ans
# 0               0.055
# 1               0.965
# d_prime:  3.410103812875415
# cued recall:
#  0.415
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      7  110
# 1.0      0   83
# contingency table norm:
#  test1    0.0    1.0
# test2
# 0.0    0.035  0.550
# 1.0    0.000  0.415
# Q:  0.8378576669112252
# recognition:
#               Yes rate
# correct_ans
# 0               0.025
# 1               0.970
# d_prime:  3.8407575926913053
# cued recall:
#  0.355
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      6  123
# 1.0      0   71
# contingency table norm:
#  test1   0.0    1.0
# test2
# 0.0    0.03  0.615
# 1.0    0.00  0.355
# Q:  0.7654320987654321
# recognition:
#               Yes rate
# correct_ans
# 0                0.02
# 1                0.97
# d_prime:  3.934542518783074
# cued recall:
#  0.4
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      6  114
# 1.0      0   80
# contingency table norm:
#  test1   0.0   1.0
# test2
# 0.0    0.03  0.57
# 1.0    0.00  0.40
# Q:  0.8027562446167097
# recognition:
#               Yes rate
# correct_ans
# 0               0.015
# 1               0.980
# d_prime:  4.223839288216383
# cued recall:
#  0.37
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      4  122
# 1.0      0   74
# contingency table norm:
#  test1   0.0   1.0
# test2
# 0.0    0.02  0.61
# 1.0    0.00  0.37
# Q:  0.691046658259773
# recognition:
#               Yes rate
# correct_ans
# 0               0.015
# 1               0.970
# d_prime:  4.050883985735812
# cued recall:
#  0.495
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      6   95
# 1.0      0   99
# contingency table norm:
#  test1   0.0    1.0
# test2
# 0.0    0.03  0.475
# 1.0    0.00  0.495
# Q:  0.8624910007199424
# recognition:
#               Yes rate
# correct_ans
# 0               0.035
# 1               0.970
# d_prime:  3.6927042811038486
# cued recall:
#  0.395
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      6  115
# 1.0      0   79
# contingency table norm:
#  test1   0.0    1.0
# test2
# 0.0    0.03  0.575
# 1.0    0.00  0.395
# Q:  0.7989556135770235
# recognition:
#               Yes rate
# correct_ans
# 0               0.000
# 1               0.975
# d_prime:  inf
# cued recall:
#  0.345
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      5  126
# 1.0      0   69
# contingency table norm:
#  test1    0.0    1.0
# test2
# 0.0    0.025  0.630
# 1.0    0.000  0.345
# Q:  0.7160493827160493
# recognition:
#               Yes rate
# correct_ans
# 0               0.025
# 1               0.980
# d_prime:  4.013712895171877
# cued recall:
#  0.37
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      3  123
# 1.0      1   73
# contingency table norm:
#  test1    0.0    1.0
# test2
# 0.0    0.015  0.615
# 1.0    0.005  0.365
# Q:  0.16271186440677965
# recognition:
#               Yes rate
# correct_ans
# 0                0.03
# 1                0.97
# d_prime:  3.7615872163025017
# cued recall:
#  0.39
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      6  116
# 1.0      0   78
# contingency table norm:
#  test1   0.0   1.0
# test2
# 0.0    0.03  0.58
# 1.0    0.00  0.39
# Q:  0.7950747581354441
# recognition:
#               Yes rate
# correct_ans
# 0               0.015
# 1               0.970
# d_prime:  4.050883985735812
# cued recall:
#  0.34
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      6  126
# 1.0      0   68
# contingency table norm:
#  test1   0.0   1.0
# test2
# 0.0    0.03  0.63
# 1.0    0.00  0.34
# Q:  0.7512291052114061
# recognition:
#               Yes rate
# correct_ans
# 0               0.025
# 1               0.995
# d_prime:  4.535793288088955
# cued recall:
#  0.45
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      1  109
# 1.0      0   90
# contingency table norm:
#  test1    0.0    1.0
# test2
# 0.0    0.005  0.545
# 1.0    0.000  0.450
# Q:  0.4251968503937008
# recognition:
#               Yes rate
# correct_ans
# 0                0.02
# 1                0.97
# d_prime:  3.934542518783074
# cued recall:
#  0.45
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0      6  104
# 1.0      0   90
# contingency table norm:
#  test1   0.0   1.0
# test2
# 0.0    0.03  0.52
# 1.0    0.00  0.45
# Q:  0.8368462138953943

# %%
print(np.array(g2_stats))
print(np.mean(np.array(g2_stats),axis=0))
print(sp.stats.sem(np.array(g2_stats),axis=0))
# Out:
# [[ 0.44        0.01        0.95        3.9712015   0.8954615 ]
#  [ 0.43        0.005       0.98        4.62957821  0.75140607]
#  [ 0.41        0.04        0.98        3.80443498  0.7327888 ]
#  [ 0.41        0.015       0.97        4.05088399  0.81012658]
#  [ 0.435       0.03        0.975       3.84075759  0.40650407]
#  [ 0.415       0.025       0.965       3.77187466  0.52452026]
#  [ 0.31        0.025       0.985       4.13005436  0.52705061]
#  [ 0.385       0.025       0.98        4.0137129   0.70746634]
#  [ 0.4         0.005       0.965       4.38773998  0.82816048]
#  [ 0.37        0.035       0.96        3.56259674  0.82888087]
#  [ 0.385       0.          0.98               inf  0.70746634]
#  [ 0.42        0.04        0.965       3.56259674  0.84095861]
#  [ 0.375       0.02        0.99        4.38009678  0.50698603]
#  [ 0.435       0.015       0.98        4.22383929  0.29242263]
#  [ 0.485       0.01        0.985       4.49643825  0.74329502]
#  [ 0.365       0.025       0.975       3.91992797  0.27565982]
#  [ 0.43        0.03        0.975       3.84075759  0.39782016]
#  [ 0.47        0.01        0.98        4.38009678 -0.06091371]
#  [ 0.415       0.055       0.965       3.41010381  0.83785767]
#  [ 0.355       0.025       0.97        3.84075759  0.7654321 ]
#  [ 0.4         0.02        0.97        3.93454252  0.80275624]
#  [ 0.37        0.015       0.98        4.22383929  0.69104666]
#  [ 0.495       0.015       0.97        4.05088399  0.862491  ]
#  [ 0.395       0.035       0.97        3.69270428  0.79895561]
#  [ 0.345       0.          0.975              inf  0.71604938]
#  [ 0.37        0.025       0.98        4.0137129   0.16271186]
#  [ 0.39        0.03        0.97        3.76158722  0.79507476]
#  [ 0.34        0.015       0.97        4.05088399  0.75122911]
#  [ 0.45        0.025       0.995       4.53579329  0.42519685]
#  [ 0.45        0.02        0.97        3.93454252  0.83684621]]
# [0.40483333 0.0215     0.97416667        inf 0.6387236 ]
# [0.00789472 0.00228878 0.00167955        nan 0.04370548]
# d:\Program Files\Anaconda3\envs\CMR_IA\lib\site-packages\numpy\core\_methods.py:236: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)

# %% [markdown]
# ### Item - CR (Group3)

# %%
tag = "Item-CR"
df_simu_g3 = simu_success(tag, params)
# Out:
# CMR2 Time: 120.63800477981567

# %%
n_subj = 30
n_per_subj = 4
g3_sesses = rng.choice(np.arange(1000),n_subj*n_per_subj,replace=False)

# %%
g3_stats = []
for i in range(n_subj):
    this_sesses = g3_sesses[n_per_subj*i:n_per_subj*(i+1)]
    this_df = df_simu_g3.loc[np.isin(df_simu_g3.session, this_sesses)].copy()    
    p_rc, hr, far, d_prime, q = anal_perform(this_df)
    g3_stats.append([p_rc, hr, far, d_prime, q])
# Out:
# recognition:
#               Yes rate
# correct_ans
# 0             0.17500
# 1             0.81875
# d_prime:  1.8452009979459503
# cued recall:
#  0.375
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     29   71
# 1.0      0   60
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.18125  0.44375
# 1.0    0.00000  0.37500
# Q:  0.9607250755287009
# recognition:
#               Yes rate
# correct_ans
# 0             0.19375
# 1             0.88125
# d_prime:  2.045418625295348
# cued recall:
#  0.48125
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     14   69
# 1.0      5   72
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.08750  0.43125
# 1.0    0.03125  0.45000
# Q:  0.46668991977677016
# recognition:
#               Yes rate
# correct_ans
# 0               0.175
# 1               0.825
# d_prime:  1.8691785821469602
# cued recall:
#  0.39375
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     25   72
# 1.0      3   60
# contingency table norm:
#  test1      0.0    1.0
# test2
# 0.0    0.15625  0.450
# 1.0    0.01875  0.375
# Q:  0.7175062621764542
# recognition:
#               Yes rate
# correct_ans
# 0             0.18750
# 1             0.81875
# d_prime:  1.797758265891346
# cued recall:
#  0.38125
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     25   74
# 1.0      4   57
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.15625  0.46250
# 1.0    0.02500  0.35625
# Q:  0.6278101582014988
# recognition:
#               Yes rate
# correct_ans
# 0             0.21250
# 1             0.76875
# d_prime:  1.5325133239324926
# cued recall:
#  0.40625
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     31   64
# 1.0      6   59
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.19375  0.40000
# 1.0    0.03750  0.36875
# Q:  0.6344015696533682
# recognition:
#               Yes rate
# correct_ans
# 0             0.15625
# 1             0.84375
# d_prime:  2.019980338499164
# cued recall:
#  0.36875
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     22   79
# 1.0      3   56
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.13750  0.49375
# 1.0    0.01875  0.35000
# Q:  0.6408518877057116
# recognition:
#               Yes rate
# correct_ans
# 0               0.225
# 1               0.775
# d_prime:  1.5108300527209386
# cued recall:
#  0.4375
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     32   58
# 1.0      4   66
# contingency table norm:
#  test1    0.0     1.0
# test2
# 0.0    0.200  0.3625
# 1.0    0.025  0.4125
# Q:  0.7828418230563002
# recognition:
#               Yes rate
# correct_ans
# 0               0.150
# 1               0.775
# d_prime:  1.7918484158542591
# cued recall:
#  0.38125
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     32   67
# 1.0      4   57
# contingency table norm:
#  test1    0.0      1.0
# test2
# 0.0    0.200  0.41875
# 1.0    0.025  0.35625
# Q:  0.7203682393555811
# recognition:
#               Yes rate
# correct_ans
# 0             0.18750
# 1             0.83125
# d_prime:  1.8462631762464783
# cued recall:
#  0.40625
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     21   74
# 1.0      6   59
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.13125  0.46250
# 1.0    0.03750  0.36875
# Q:  0.4508080521689821
# recognition:
#               Yes rate
# correct_ans
# 0             0.21875
# 1             0.81250
# d_prime:  1.6635683201668037
# cued recall:
#  0.39375
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     28   69
# 1.0      2   61
# contingency table norm:
#  test1     0.0      1.0
# test2
# 0.0    0.1750  0.43125
# 1.0    0.0125  0.38125
# Q:  0.8196210744874124
# recognition:
#               Yes rate
# correct_ans
# 0              0.2000
# 1              0.8125
# d_prime:  1.7287677925917901
# cued recall:
#  0.5125
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     26   52
# 1.0      4   78
# contingency table norm:
#  test1     0.0     1.0
# test2
# 0.0    0.1625  0.3250
# 1.0    0.0250  0.4875
# Q:  0.796028491258364
# recognition:
#               Yes rate
# correct_ans
# 0             0.18125
# 1             0.75000
# d_prime:  1.5851014570685518
# cued recall:
#  0.46875
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     32   53
# 1.0      8   67
# contingency table norm:
#  test1   0.0      1.0
# test2
# 0.0    0.20  0.33125
# 1.0    0.05  0.41875
# Q:  0.6565980743817255
# recognition:
#               Yes rate
# correct_ans
# 0             0.23750
# 1             0.81875
# d_prime:  1.6249791471526578
# cued recall:
#  0.46875
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     24   61
# 1.0      5   70
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.15000  0.38125
# 1.0    0.03125  0.43750
# Q:  0.6724763979665941
# recognition:
#               Yes rate
# correct_ans
# 0             0.18125
# 1             0.78750
# d_prime:  1.7083885529977083
# cued recall:
#  0.3375
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     30   76
# 1.0      4   50
# contingency table norm:
#  test1     0.0     1.0
# test2
# 0.0    0.1875  0.4750
# 1.0    0.0250  0.3125
# Q:  0.6346511010878217
# recognition:
#               Yes rate
# correct_ans
# 0             0.18750
# 1             0.78125
# d_prime:  1.6635683201668037
# cued recall:
#  0.4
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     31   65
# 1.0      4   60
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.19375  0.40625
# 1.0    0.02500  0.37500
# Q:  0.7321063394683026
# recognition:
#               Yes rate
# correct_ans
# 0             0.24375
# 1             0.81875
# d_prime:  1.6049022825755532
# cued recall:
#  0.38125
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     27   72
# 1.0      2   59
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.16875  0.45000
# 1.0    0.01250  0.36875
# Q:  0.8005502063273727
# recognition:
#               Yes rate
# correct_ans
# 0              0.1375
# 1              0.8250
# d_prime:  2.0262096585076477
# cued recall:
#  0.48125
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     21   62
# 1.0      7   70
# contingency table norm:
#  test1      0.0     1.0
# test2
# 0.0    0.13125  0.3875
# 1.0    0.04375  0.4375
# Q:  0.527588813303099
# recognition:
#               Yes rate
# correct_ans
# 0             0.24375
# 1             0.88125
# d_prime:  1.875549196680123
# cued recall:
#  0.4875
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     16   66
# 1.0      3   75
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.10000  0.41250
# 1.0    0.01875  0.46875
# Q:  0.6851538721677376
# recognition:
#               Yes rate
# correct_ans
# 0             0.25625
# 1             0.85625
# d_prime:  1.7185718554384057
# cued recall:
#  0.40625
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     19   76
# 1.0      4   61
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.11875  0.47500
# 1.0    0.02500  0.38125
# Q:  0.5539358600583091
# recognition:
#               Yes rate
# correct_ans
# 0              0.1875
# 1              0.8625
# d_prime:  1.9787669264530443
# cued recall:
#  0.35
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     20   84
# 1.0      2   54
# contingency table norm:
#  test1     0.0     1.0
# test2
# 0.0    0.1250  0.5250
# 1.0    0.0125  0.3375
# Q:  0.681972149040271
# recognition:
#               Yes rate
# correct_ans
# 0             0.23125
# 1             0.80000
# d_prime:  1.5763577113801688
# cued recall:
#  0.4375
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     25   65
# 1.0      7   63
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.15625  0.40625
# 1.0    0.04375  0.39375
# Q:  0.5344705046197583
# recognition:
#               Yes rate
# correct_ans
# 0             0.16875
# 1             0.87500
# d_prime:  2.10946599760361
# cued recall:
#  0.35625
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     19   84
# 1.0      1   56
# contingency table norm:
#  test1      0.0    1.0
# test2
# 0.0    0.11875  0.525
# 1.0    0.00625  0.350
# Q:  0.7936507936507936
# recognition:
#               Yes rate
# correct_ans
# 0             0.26250
# 1             0.86875
# d_prime:  1.7561587807722834
# cued recall:
#  0.40625
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     19   76
# 1.0      2   63
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.11875  0.47500
# 1.0    0.01250  0.39375
# Q:  0.7324239244491081
# recognition:
#               Yes rate
# correct_ans
# 0             0.21250
# 1             0.83125
# d_prime:  1.7568934633528406
# cued recall:
#  0.44375
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     20   69
# 1.0      7   64
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.12500  0.43125
# 1.0    0.04375  0.40000
# Q:  0.43449959316517495
# recognition:
#               Yes rate
# correct_ans
# 0              0.2125
# 1              0.8500
# d_prime:  1.834210235619028
# cued recall:
#  0.5
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     23   57
# 1.0      1   79
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.14375  0.35625
# 1.0    0.00625  0.49375
# Q:  0.9117421335379893
# recognition:
#               Yes rate
# correct_ans
# 0             0.12500
# 1             0.80625
# d_prime:  2.0145093846943163
# cued recall:
#  0.5
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     21   59
# 1.0     10   70
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.13125  0.36875
# 1.0    0.06250  0.43750
# Q:  0.41625788367203925
# recognition:
#               Yes rate
# correct_ans
# 0             0.16875
# 1             0.83750
# d_prime:  1.9433515776739272
# cued recall:
#  0.41875
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     23   70
# 1.0      3   64
# contingency table norm:
#  test1      0.0     1.0
# test2
# 0.0    0.14375  0.4375
# 1.0    0.01875  0.4000
# Q:  0.72
# recognition:
#               Yes rate
# correct_ans
# 0             0.20625
# 1             0.82500
# d_prime:  1.7540913986417341
# cued recall:
#  0.45625
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     20   67
# 1.0      8   65
# contingency table norm:
#  test1    0.0      1.0
# test2
# 0.0    0.125  0.41875
# 1.0    0.050  0.40625
# Q:  0.4012522828072006
# recognition:
#               Yes rate
# correct_ans
# 0             0.21250
# 1             0.85625
# d_prime:  1.8613987844629578
# cued recall:
#  0.45625
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     18   69
# 1.0      5   68
# contingency table norm:
#  test1      0.0      1.0
# test2
# 0.0    0.11250  0.43125
# 1.0    0.03125  0.42500
# Q:  0.5365262200666868
# recognition:
#               Yes rate
# correct_ans
# 0              0.2125
# 1              0.8750
# d_prime:  1.948126226501246
# cued recall:
#  0.45
# contingency table:
#  test1  0.0  1.0
# test2
# 0.0     18   70
# 1.0      2   70
# contingency table norm:
#  test1     0.0     1.0
# test2
# 0.0    0.1125  0.4375
# 1.0    0.0125  0.4375
# Q:  0.7619047619047619

# %%
print(np.array(g3_stats))
print(np.mean(np.array(g3_stats),axis=0))
print(sp.stats.sem(np.array(g3_stats),axis=0))
# Out:
# [[0.375      0.175      0.81875    1.845201   0.96072508]
#  [0.48125    0.19375    0.88125    2.04541863 0.46668992]
#  [0.39375    0.175      0.825      1.86917858 0.71750626]
#  [0.38125    0.1875     0.81875    1.79775827 0.62781016]
#  [0.40625    0.2125     0.76875    1.53251332 0.63440157]
#  [0.36875    0.15625    0.84375    2.01998034 0.64085189]
#  [0.4375     0.225      0.775      1.51083005 0.78284182]
#  [0.38125    0.15       0.775      1.79184842 0.72036824]
#  [0.40625    0.1875     0.83125    1.84626318 0.45080805]
#  [0.39375    0.21875    0.8125     1.66356832 0.81962107]
#  [0.5125     0.2        0.8125     1.72876779 0.79602849]
#  [0.46875    0.18125    0.75       1.58510146 0.65659807]
#  [0.46875    0.2375     0.81875    1.62497915 0.6724764 ]
#  [0.3375     0.18125    0.7875     1.70838855 0.6346511 ]
#  [0.4        0.1875     0.78125    1.66356832 0.73210634]
#  [0.38125    0.24375    0.81875    1.60490228 0.80055021]
#  [0.48125    0.1375     0.825      2.02620966 0.52758881]
#  [0.4875     0.24375    0.88125    1.8755492  0.68515387]
#  [0.40625    0.25625    0.85625    1.71857186 0.55393586]
#  [0.35       0.1875     0.8625     1.97876693 0.68197215]
#  [0.4375     0.23125    0.8        1.57635771 0.5344705 ]
#  [0.35625    0.16875    0.875      2.109466   0.79365079]
#  [0.40625    0.2625     0.86875    1.75615878 0.73242392]
#  [0.44375    0.2125     0.83125    1.75689346 0.43449959]
#  [0.5        0.2125     0.85       1.83421024 0.91174213]
#  [0.5        0.125      0.80625    2.01450938 0.41625788]
#  [0.41875    0.16875    0.8375     1.94335158 0.72      ]
#  [0.45625    0.20625    0.825      1.7540914  0.40125228]
#  [0.45625    0.2125     0.85625    1.86139878 0.53652622]
#  [0.45       0.2125     0.875      1.94812623 0.76190476]]
# [0.42479167 0.19833333 0.825625   1.79973096 0.66018045]
# [0.0089473  0.00620626 0.00646436 0.02992297 0.02634844]
